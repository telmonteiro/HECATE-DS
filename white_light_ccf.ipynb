# %% [markdown]
# Sadly, I lost all my previous codes. So I will speedrun the adaptation of white light CCF in this notebook.
#
# For now, I will ignore the part of profile fitting. I just want to extract the local spectra.
#
# Also only the 11/08/2021 night.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import dfitspy
import os
import glob
from matplotlib.colors import Normalize
from scipy.sparse import lil_matrix
from scipy.stats import spearmanr

from ldtk import LDPSetCreator, BoxcarFilter
import SOAP # type: ignore

# %%
#### Folder where the images are located
directory_path = 'Eduardos_code/white_light_ccfs/'
listfiles=glob.glob(os.path.join(directory_path, '*.fits'))

listkeys=['DATE-OBS','HIERARCH ESO QC BJD']
fitsort = dfitspy.dfitsort(listfiles, listkeys,exact=True)
dfitspy.dfitsort_view(fitsort)
# Out:
#                     filename                     	       DATE-OBS        	HIERARCH ESO QC BJD
# -------------------------------------------------	-----------------------	-------------------
# r.ESPRE.2021-08-31T02_39_59.908_CCF_SKYSUB_A.fits	2021-08-31T02:39:59.908	 2459457.61727296
# r.ESPRE.2021-08-31T02_58_01.354_CCF_SKYSUB_A.fits	2021-08-31T02:58:01.354	 2459457.62995938
# r.ESPRE.2021-08-31T04_34_15.697_CCF_SKYSUB_A.fits	2021-08-31T04:34:15.697	  2459457.6967514
# r.ESPRE.2021-08-31T00_51_49.573_CCF_SKYSUB_A.fits	2021-08-31T00:51:49.573	 2459457.54226715
# r.ESPRE.2021-08-11T00_51_07.338_CCF_SKYSUB_A.fits	2021-08-11T00:51:07.338	 2459437.54224261
# r.ESPRE.2021-08-11T01_45_19.180_CCF_SKYSUB_A.fits	2021-08-11T01:45:19.180	 2459437.57993129
# r.ESPRE.2021-08-11T04_39_24.065_CCF_SKYSUB_A.fits	2021-08-11T04:39:24.064	 2459437.70013906
# r.ESPRE.2021-08-31T03_28_05.180_CCF_SKYSUB_A.fits	2021-08-31T03:28:05.179	 2459457.65081538
# r.ESPRE.2021-08-11T03_45_22.093_CCF_SKYSUB_A.fits	2021-08-11T03:45:22.093	 2459437.66325562
# r.ESPRE.2021-08-31T04_10_12.276_CCF_SKYSUB_A.fits	2021-08-31T04:10:12.275	 2459457.68004575
# r.ESPRE.2021-08-11T02_57_20.533_CCF_SKYSUB_A.fits	2021-08-11T02:57:20.533	 2459437.62999147
# r.ESPRE.2021-08-11T02_45_18.607_CCF_SKYSUB_A.fits	2021-08-11T02:45:18.606	 2459437.62153524
# r.ESPRE.2021-08-11T03_33_23.219_CCF_SKYSUB_A.fits	2021-08-11T03:33:23.219	 2459437.65495973
# r.ESPRE.2021-08-11T04_09_20.370_CCF_SKYSUB_A.fits	2021-08-11T04:09:20.370	 2459437.67988129
# r.ESPRE.2021-08-31T03_40_04.486_CCF_SKYSUB_A.fits	2021-08-31T03:40:04.486	 2459457.65911262
# r.ESPRE.2021-08-11T01_39_17.063_CCF_SKYSUB_A.fits	2021-08-11T01:39:17.062	  2459437.5757228
# r.ESPRE.2021-08-31T03_10_03.164_CCF_SKYSUB_A.fits	2021-08-31T03:10:03.163	 2459457.63828904
# r.ESPRE.2021-08-31T04_04_10.226_CCF_SKYSUB_A.fits	2021-08-31T04:04:10.225	  2459457.6758069
# r.ESPRE.2021-08-11T04_33_24.353_CCF_SKYSUB_A.fits	2021-08-11T04:33:24.353	 2459437.69668064
# r.ESPRE.2021-08-31T03_22_05.297_CCF_SKYSUB_A.fits	2021-08-31T03:22:05.297	 2459457.64668496
# r.ESPRE.2021-08-31T03_58_08.053_CCF_SKYSUB_A.fits	2021-08-31T03:58:08.052	  2459457.6717437
# r.ESPRE.2021-08-11T01_33_17.472_CCF_SKYSUB_A.fits	2021-08-11T01:33:17.471	 2459437.57156092
# r.ESPRE.2021-08-31T00_45_49.880_CCF_SKYSUB_A.fits	2021-08-31T00:45:49.879	 2459457.53806945
# r.ESPRE.2021-08-11T02_39_18.803_CCF_SKYSUB_A.fits	2021-08-11T02:39:18.802	 2459437.61743687
# r.ESPRE.2021-08-11T04_21_22.562_CCF_SKYSUB_A.fits	2021-08-11T04:21:22.561	 2459437.68832668
# r.ESPRE.2021-08-11T02_03_20.368_CCF_SKYSUB_A.fits	2021-08-11T02:03:20.368	  2459437.5923685
# r.ESPRE.2021-08-31T01_57_56.893_CCF_SKYSUB_A.fits	2021-08-31T01:57:56.892	 2459457.58822522
# r.ESPRE.2021-08-11T02_21_18.097_CCF_SKYSUB_A.fits	2021-08-11T02:21:18.096	 2459437.60485594
# r.ESPRE.2021-08-11T04_45_26.222_CCF_SKYSUB_A.fits	2021-08-11T04:45:26.221	 2459437.70499729
# r.ESPRE.2021-08-31T01_51_57.797_CCF_SKYSUB_A.fits	2021-08-31T01:51:57.797	 2459457.58408653
# r.ESPRE.2021-08-31T04_16_11.909_CCF_SKYSUB_A.fits	2021-08-31T04:16:11.908	 2459457.68423579
# r.ESPRE.2021-08-31T03_16_03.112_CCF_SKYSUB_A.fits	2021-08-31T03:16:03.112	 2459457.64247927
# r.ESPRE.2021-08-31T02_34_00.206_CCF_SKYSUB_A.fits	2021-08-31T02:34:00.205	 2459457.61321405
# r.ESPRE.2021-08-11T01_03_09.477_CCF_SKYSUB_A.fits	2021-08-11T01:03:09.477	 2459437.55073254
# r.ESPRE.2021-08-31T04_28_13.592_CCF_SKYSUB_A.fits	2021-08-31T04:28:13.592	 2459457.69256053
# r.ESPRE.2021-08-11T00_57_07.347_CCF_SKYSUB_A.fits	2021-08-11T00:57:07.347	 2459437.54637113
# r.ESPRE.2021-08-31T03_04_01.101_CCF_SKYSUB_A.fits	2021-08-31T03:04:01.101	 2459457.63405352
# r.ESPRE.2021-08-31T00_27_45.656_CCF_SKYSUB_A.fits	2021-08-31T00:27:45.656	 2459457.52544811
# r.ESPRE.2021-08-11T01_57_18.180_CCF_SKYSUB_A.fits	2021-08-11T01:57:18.180	 2459437.58822865
# r.ESPRE.2021-08-31T02_03_56.546_CCF_SKYSUB_A.fits	2021-08-31T02:03:56.545	 2459457.59231133
# r.ESPRE.2021-08-11T01_51_18.608_CCF_SKYSUB_A.fits	2021-08-11T01:51:18.607	 2459437.58413642
# r.ESPRE.2021-08-31T03_34_04.486_CCF_SKYSUB_A.fits	2021-08-31T03:34:04.486	 2459457.65511276
# r.ESPRE.2021-08-11T03_57_21.598_CCF_SKYSUB_A.fits	2021-08-11T03:57:21.597	 2459437.67163866
# r.ESPRE.2021-08-11T03_03_22.607_CCF_SKYSUB_A.fits	2021-08-11T03:03:22.606	 2459437.63412999
# r.ESPRE.2021-08-31T04_40_15.553_CCF_SKYSUB_A.fits	2021-08-31T04:40:15.553	 2459457.70096486
# r.ESPRE.2021-08-31T01_27_54.267_CCF_SKYSUB_A.fits	2021-08-31T01:27:54.267	 2459457.56731017
# r.ESPRE.2021-08-11T03_27_23.534_CCF_SKYSUB_A.fits	2021-08-11T03:27:23.533	 2459437.65081759
# r.ESPRE.2021-08-31T02_21_58.580_CCF_SKYSUB_A.fits	2021-08-31T02:21:58.580	 2459457.60491082
# r.ESPRE.2021-08-31T02_27_58.106_CCF_SKYSUB_A.fits	2021-08-31T02:27:58.106	  2459457.6090024
# r.ESPRE.2021-08-11T02_51_20.769_CCF_SKYSUB_A.fits	2021-08-11T02:51:20.769	 2459437.62574425
# r.ESPRE.2021-08-11T02_27_17.370_CCF_SKYSUB_A.fits	2021-08-11T02:27:17.370	 2459437.60920859
# r.ESPRE.2021-08-31T00_33_47.806_CCF_SKYSUB_A.fits	2021-08-31T00:33:47.806	 2459457.52985131
# r.ESPRE.2021-08-31T01_45_55.618_CCF_SKYSUB_A.fits	2021-08-31T01:45:55.618	 2459457.57988785
# r.ESPRE.2021-08-31T02_09_58.591_CCF_SKYSUB_A.fits	2021-08-31T02:09:58.590	 2459457.59652929
# r.ESPRE.2021-08-11T01_27_15.262_CCF_SKYSUB_A.fits	2021-08-11T01:27:15.262	 2459437.56746249
# r.ESPRE.2021-08-11T02_33_16.597_CCF_SKYSUB_A.fits	2021-08-11T02:33:16.597	 2459437.61325515
# r.ESPRE.2021-08-11T01_09_08.919_CCF_SKYSUB_A.fits	2021-08-11T01:09:08.919	 2459437.55483714
# r.ESPRE.2021-08-31T00_57_51.727_CCF_SKYSUB_A.fits	2021-08-31T00:57:51.726	 2459457.54660442
# r.ESPRE.2021-08-11T03_09_22.101_CCF_SKYSUB_A.fits	2021-08-11T03:09:22.101	 2459437.63825951
# r.ESPRE.2021-08-11T03_21_23.890_CCF_SKYSUB_A.fits	2021-08-11T03:21:23.890	 2459437.64662733
# r.ESPRE.2021-08-11T02_09_19.508_CCF_SKYSUB_A.fits	2021-08-11T02:09:19.507	 2459437.59662237
# r.ESPRE.2021-08-11T01_15_11.028_CCF_SKYSUB_A.fits	2021-08-11T01:15:11.027	 2459437.55901774
# r.ESPRE.2021-08-11T04_03_20.918_CCF_SKYSUB_A.fits	2021-08-11T04:03:20.918	 2459437.67586338
# r.ESPRE.2021-08-31T02_15_58.565_CCF_SKYSUB_A.fits	2021-08-31T02:15:58.565	 2459457.60071982
# r.ESPRE.2021-08-31T01_03_51.127_CCF_SKYSUB_A.fits	2021-08-31T01:03:51.127	 2459457.55062859
# r.ESPRE.2021-08-31T01_09_53.231_CCF_SKYSUB_A.fits	2021-08-31T01:09:53.231	  2459457.5548646
# r.ESPRE.2021-08-31T01_21_52.184_CCF_SKYSUB_A.fits	2021-08-31T01:21:52.184	 2459457.56314385
# r.ESPRE.2021-08-31T03_52_05.909_CCF_SKYSUB_A.fits	2021-08-31T03:52:05.908	  2459457.6674621
# r.ESPRE.2021-08-31T02_51_59.254_CCF_SKYSUB_A.fits	2021-08-31T02:51:59.253	 2459457.62573382
# r.ESPRE.2021-08-11T03_51_21.598_CCF_SKYSUB_A.fits	2021-08-11T03:51:21.597	 2459437.66742344
# r.ESPRE.2021-08-11T04_15_22.590_CCF_SKYSUB_A.fits	2021-08-11T04:15:22.589	  2459437.6842472
# r.ESPRE.2021-08-11T00_45_08.116_CCF_SKYSUB_A.fits	2021-08-11T00:45:08.115	 2459437.53831415
# r.ESPRE.2021-08-11T04_27_22.204_CCF_SKYSUB_A.fits	2021-08-11T04:27:22.204	 2459437.69250305
# r.ESPRE.2021-08-31T03_46_06.652_CCF_SKYSUB_A.fits	2021-08-31T03:46:06.651	 2459457.66341877
# r.ESPRE.2021-08-31T01_33_53.783_CCF_SKYSUB_A.fits	2021-08-31T01:33:53.783	 2459457.57151622
# r.ESPRE.2021-08-31T01_39_55.908_CCF_SKYSUB_A.fits	2021-08-31T01:39:55.908	 2459457.57569344
# r.ESPRE.2021-08-31T04_22_11.507_CCF_SKYSUB_A.fits	2021-08-31T04:22:11.506	  2459457.6883664
# r.ESPRE.2021-08-11T02_15_19.062_CCF_SKYSUB_A.fits	2021-08-11T02:15:19.061	 2459437.60070744
# r.ESPRE.2021-08-31T02_45_59.902_CCF_SKYSUB_A.fits	2021-08-31T02:45:59.901	 2459457.62165119
# r.ESPRE.2021-08-11T01_21_13.130_CCF_SKYSUB_A.fits	2021-08-11T01:21:13.130	 2459437.56316703
# r.ESPRE.2021-08-31T00_39_47.752_CCF_SKYSUB_A.fits	2021-08-31T00:39:47.752	 2459457.53394776
# r.ESPRE.2021-08-31T01_15_52.721_CCF_SKYSUB_A.fits	2021-08-31T01:15:52.721	 2459457.55900785
# r.ESPRE.2021-08-11T03_39_22.784_CCF_SKYSUB_A.fits	2021-08-11T03:39:22.784	  2459437.6591595
# r.ESPRE.2021-08-11T03_15_24.258_CCF_SKYSUB_A.fits	2021-08-11T03:15:24.257	 2459437.64249274

# %%
#List files names in order
list_ccfs = []
for name in listfiles:
    if '2021-08-11' in name and 'SKY' in name:
        list_ccfs.append(name)
print(len(list_ccfs),list_ccfs)

list_ccfs = sorted(list_ccfs)

#removing low SNR observation
list_ccfs = list_ccfs[:-1]

print(len(list_ccfs),list_ccfs)
# Out:
# 41 ['Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_51_07.338_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_45_19.180_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_39_24.065_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_45_22.093_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_57_20.533_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_45_18.607_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_33_23.219_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_09_20.370_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_39_17.063_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_33_24.353_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_33_17.472_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_39_18.803_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_21_22.562_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_03_20.368_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_21_18.097_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_45_26.222_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_03_09.477_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_57_07.347_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_57_18.180_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_51_18.608_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_57_21.598_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_03_22.607_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_27_23.534_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_51_20.769_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_27_17.370_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_27_15.262_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_33_16.597_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_09_08.919_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_09_22.101_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_21_23.890_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_09_19.508_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_15_11.028_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_03_20.918_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_51_21.598_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_15_22.590_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_45_08.116_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_27_22.204_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_15_19.062_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_21_13.130_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_39_22.784_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_15_24.258_CCF_SKYSUB_A.fits']
# 40 ['Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_45_08.116_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_51_07.338_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_57_07.347_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_03_09.477_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_09_08.919_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_15_11.028_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_21_13.130_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_27_15.262_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_33_17.472_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_39_17.063_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_45_19.180_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_51_18.608_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T01_57_18.180_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_03_20.368_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_09_19.508_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_15_19.062_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_21_18.097_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_27_17.370_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_33_16.597_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_39_18.803_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_45_18.607_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_51_20.769_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T02_57_20.533_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_03_22.607_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_09_22.101_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_15_24.258_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_21_23.890_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_27_23.534_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_33_23.219_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_39_22.784_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_45_22.093_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_51_21.598_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T03_57_21.598_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_03_20.918_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_09_20.370_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_15_22.590_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_21_22.562_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_27_22.204_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_33_24.353_CCF_SKYSUB_A.fits', 'Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T04_39_24.065_CCF_SKYSUB_A.fits']

# %%
file_test = directory_path+'r.ESPRE.2021-08-11T00_51_07.338_CCF_SKYSUB_A.fits'

hdutest = fits.open(file_test)
hdutest.info()
hdutest.close()
# Out:
# Filename: Eduardos_code/white_light_ccfs/r.ESPRE.2021-08-11T00_51_07.338_CCF_SKYSUB_A.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1474   ()
#   1  SCIDATA       1 ImageHDU        10   (81, 171)   float32
#   2  ERRDATA       1 ImageHDU        10   (81, 171)   float32
#   3  QUALDATA      1 ImageHDU        10   (81, 171)   int32

# %%
#checking the header
f = fits.getdata(file_test,1)
f1 = fits.getdata(file_test,2)
fh = fits.getheader(file_test)
fh #HIERARCH ESO OBS START
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2021-08-12T00:29:10' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U1'         / ESO <TEL>
# INSTRUME= 'ESPRESSO'           / Instrument used.
# OBJECT  = 'HD 189733'          / Original target.
# RA      =           300.182485 / [deg] 20:00:43.7 RA (J2000) pointing
# DEC     =             22.70932 / [deg] 22:42:33.5 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate system
# EXPTIME =                 300. / Integration time
# MJD-OBS =        59437.0355016 / Obs start
# DATE-OBS= '2021-08-11T00:51:07.338' / Observing date
# UTC     =                3055. / [s] 00:50:55.000 UTC
# LST     =             62888.91 / [s] 17:28:08.910 LST
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# ARCFILE = 'ESPRE.2021-08-11T00:51:07.338.fits' / Archive File Name
# DATAMD5 = '83d8032531358d60382fbba84376da13' / MD5 checksum
# PIPEFILE= 'ESPRESSO_CCF_SKYSUB_A.fits' / Filename of data product
# HIERARCH ESO OBS AIRM =    2.8 / Req. max. airmass
# HIERARCH ESO OBS AMBI FWHM = 2. / Req. max. seeing
# HIERARCH ESO OBS AMBI TRANS = '3THN    ' / Req. sky transparency
# HIERARCH ESO OBS AOMODE = 'NO_AO   ' / Req. AO mode
# HIERARCH ESO OBS CONTAINER ID = 2658931 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE = 'U       ' / Scheduling container type
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-2.2' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 15503 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID =  3095158 / Observation block ID
# HIERARCH ESO OBS MOON DIST = 30 / Req. min. angular dist. from moon [deg]
# HIERARCH ESO OBS MOON FLI = 1. / Req. max. fractional lunar illum.
# HIERARCH ESO OBS NAME = 'HD-189733b-transit' / OB name
# HIERARCH ESO OBS NTPL =      2 / Number of templates within OB
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 53322 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '1104.C-0350(T)' / ESO program identification
# HIERARCH ESO OBS START = '2021-08-11T00:36:11' / OB start time
# HIERARCH ESO OBS TARG NAME = 'HD 189733' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OBS TWILIGHT =  0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR = 30. / Req. water vapour
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =     2 / Exposure number within template
# HIERARCH ESO TPL ID = 'ESPRESSO_singleHR_obs' / Template signature ID
# HIERARCH ESO TPL NAME = 'ESPRESSO_singleHR_obs' / Template name
# HIERARCH ESO TPL NEXP =     41 / Number of exposures within template
# HIERARCH ESO TPL PRESEQ = 'ESPRESSO_obs.seq' / Sequencer script
# HIERARCH ESO TPL START = '2021-08-11T00:44:34' / TPL start time
# HIERARCH ESO TPL VERSION = '$Revision: 328721 $' / Version of the template
# HIERARCH ESO TEL1 AIRM END = 1.959 / Airmass at end
# HIERARCH ESO TEL1 AIRM START = 2.01 / Airmass at start
# HIERARCH ESO TEL1 ALT =  29.74 / [deg] Alt angle at start
# HIERARCH ESO TEL1 AMBI FWHM END = 0.49 / [arcsec] Observatory Seeing queried fro
# HIERARCH ESO TEL1 AMBI FWHM START = 0.48 / [arcsec] Observatory Seeing queried f
# HIERARCH ESO TEL1 AMBI IRSKY TEMP = -99. / Temperature of the IR sky, from radi
# HIERARCH ESO TEL1 AMBI IWV END = 0. / Integrated Water Vapor
# HIERARCH ESO TEL1 AMBI IWV START = 0. / Integrated Water Vapor
# HIERARCH ESO TEL1 AMBI IWV30D END = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL1 AMBI IWV30D START = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL1 AMBI IWV30DSTD END = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL1 AMBI IWV30DSTD START = 0. / IWV at 30deg elev.
# HIERARCH ESO TEL1 AMBI IWVSTD END = 0. / Standard Deviation of Integrated Wate
# HIERARCH ESO TEL1 AMBI IWVSTD START = 0. / Standard Deviation of Integrated Wa
# HIERARCH ESO TEL1 AMBI PRES END = 744. / [hPa] Observatory ambient air pressur
# HIERARCH ESO TEL1 AMBI PRES START = 744. / [hPa] Observatory ambient air press
# HIERARCH ESO TEL1 AMBI RHUM = 3. / [%] Observatory ambient relative humidity qu
# HIERARCH ESO TEL1 AMBI TAU0 = 0.0039 / [s] Average coherence time
# HIERARCH ESO TEL1 AMBI TEMP = 11.5 / [deg C] Observatory ambient temperature qu
# HIERARCH ESO TEL1 AMBI WINDDIR = 6.5 / [deg] Observatory ambient wind direction
# HIERARCH ESO TEL1 AMBI WINDSP = 5. / [m/s] Observatory ambient wind speed quer
# HIERARCH ESO TEL1 AZ = 221.243 / [deg] Az angle at start S=0,W=90
# HIERARCH ESO TEL1 CHOP ST =  F / True when chopping is active
# HIERARCH ESO TEL1 DATE = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL1 DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TELi
# HIERARCH ESO TEL1 DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL1 FO POS =  0. / Adapter focus position during tracking
# HIERARCH ESO TEL1 FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL1 FOCU LEN = 120. / [m] Focal length
# HIERARCH ESO TEL1 FOCU SCALE = 1.718 / [arcsec/mm] Focal scale
# HIERARCH ESO TEL1 FOCU VALUE = -36.743 / [mm] M2 setting
# HIERARCH ESO TEL1 GEOELEV = 2648. / [m] Elevation above sea level
# HIERARCH ESO TEL1 GEOLAT = -24.6276 / [deg] Tel geo latitute (+=North)
# HIERARCH ESO TEL1 GEOLON = -70.4051 / [deg] Tel geo longitude (+=East)
# HIERARCH ESO TEL1 IA FWHM = 0.64 / [arcsec] Delivered seeing corrected by airmas
# HIERARCH ESO TEL1 IA FWHMLIN = 0.71 / Delivered seeing on IA detector (linear fi
# HIERARCH ESO TEL1 IA FWHMLINOBS = 1.07 / Delivered seeing on IA detector (linear
# HIERARCH ESO TEL1 ID = 'v 329893' / TCS version number
# HIERARCH ESO TEL1 MOON DEC = 9.29264 / [deg] 09:17:33.5 DEC (J2000)
# HIERARCH ESO TEL1 MOON RA = 170.956322 / [deg] 11:23:49.5 RA (J2000)
# HIERARCH ESO TEL1 OPER = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL1 PARANG END = -140.646 / [deg] Parallactic angle at end
# HIERARCH ESO TEL1 PARANG START = -139.466 / [deg] Parallactic angle at start
# HIERARCH ESO TEL1 TARG ALPHA = 200043.713 / Alpha coordinate for the target
# HIERARCH ESO TEL1 TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=appare
# HIERARCH ESO TEL1 TARG DELTA = 224239.071 / Delta coordinate for the target
# HIERARCH ESO TEL1 TARG EPOCH = 2000. / [yr] Epoch 1950 or 2000
# HIERARCH ESO TEL1 TARG EPOCHSYSTEM = 'J       ' / Epoch system (J=Julian / B=Bes
# HIERARCH ESO TEL1 TARG EQUINOX = 2000. / [yr] Equinox
# HIERARCH ESO TEL1 TARG PARALLAX = 0. / [arcsec] Parallax
# HIERARCH ESO TEL1 TARG PMA = -0.003294 / [arcsec/yr] Proper Motion Alpha
# HIERARCH ESO TEL1 TARG PMD = -0.25022 / [arcsec/yr] Proper motion Delta
# HIERARCH ESO TEL1 TARG RADVEL = 0. / [km/s] Radial velocity
# HIERARCH ESO TEL1 TH M1 TEMP = 10.49 / [deg C] M1 superficial temperature
# HIERARCH ESO TEL1 TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO INS ADC1 DEC = 224613.51166 / [deg] Telescope desclination.
# HIERARCH ESO INS ADC1 ENC = 78022 / [Enc] ADC absolute position.
# HIERARCH ESO INS ADC1 ID =   0 / ADC unique id
# HIERARCH ESO INS ADC1 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC1 NAME = 'ADC UT1 wheel 1' / ADC name
# HIERARCH ESO INS ADC1 POS = 133.672906 / [deg] Position in user units
# HIERARCH ESO INS ADC1 POSANG = 133.6729 / Position angle [deg].
# HIERARCH ESO INS ADC1 RA = 200140.338105 / [deg] Telescope right ascension.
# HIERARCH ESO INS ADC1 SENS1 = 744. / [mbar] Pressure.
# HIERARCH ESO INS ADC1 TEMP = 11.5 / [C] Temperature.
# HIERARCH ESO INS ADC2 DEC = 224613.51166 / [deg] Telescope desclination.
# HIERARCH ESO INS ADC2 ENC = 147373 / [Enc] ADC absolute position.
# HIERARCH ESO INS ADC2 ID =   0 / ADC unique id
# HIERARCH ESO INS ADC2 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC2 NAME = 'ADC UT1 wheel 2' / ADC name
# HIERARCH ESO INS ADC2 POS = 252.49007 / [deg] Position in user units
# HIERARCH ESO INS ADC2 POSANG = 252.4901 / Position angle [deg].
# HIERARCH ESO INS ADC2 RA = 200140.338105 / [deg] Telescope right ascension.
# HIERARCH ESO INS ADC2 SENS1 = 744. / [mbar] Pressure.
# HIERARCH ESO INS ADC2 TEMP = 11.5 / [C] Temperature.
# HIERARCH ESO INS CALSEL ENC = 30011 / [Enc] Component absolute position.
# HIERARCH ESO INS CALSEL ID = 'TRG_SKY ' / Unique ID.
# HIERARCH ESO INS CALSEL NAME = 'TRG_SKY ' / FE Calibration selector.
# HIERARCH ESO INS CALSEL NO = 1 / CALSEL slot number.
# HIERARCH ESO INS CALSEL POS = 15.0055 / [mm] Component position.
# HIERARCH ESO INS CALSEL TYPE = 'MASK    ' / OPTIi element.
# HIERARCH ESO INS DATE = '2012-10-16' / Instrument release date (yyyy-mm-dd).
# HIERARCH ESO INS DID1 = 'ESPRESSO_ICS-296578' / Data dictionary for INS.
# HIERARCH ESO INS DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS FILT1 ENC = 78519 / [Enc] FS Filter wheel absolute position.
# HIERARCH ESO INS FILT1 ID = 'ND_200-0.50' / FS Filter unique id.
# HIERARCH ESO INS FILT1 NAME = 'FSND20  ' / FS Filter name.
# HIERARCH ESO INS FILT1 NO =  3 / FS Filter wheel position index.
# HIERARCH ESO INS FILT1 POS = 120.0005 / [deg] Component position.
# HIERARCH ESO INS FILT1 TYPE = 'FILTER  ' / FS OPTIi element.
# HIERARCH ESO INS FOCU ENC = 28014 / [Enc] Absolute position.
# HIERARCH ESO INS FOCU ID =   0 / Unique id
# HIERARCH ESO INS FOCU NAME = 'Focusing stage UT1' / Name
# HIERARCH ESO INS FOCU POS = 14. / [mm] Position.
# HIERARCH ESO INS ID = 'ESPRESSO/ESPRESSO' / Instrument ID.
# HIERARCH ESO INS MODE = 'SINGLEHR' / Instrument mode used.
# HIERARCH ESO INS PATH = '        ' / Optical path used.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TILT1 ENG2ARCX = 0.0003 / Conversion factor from engineering u
# HIERARCH ESO INS TILT1 ENG2ARCY = 0.0002 / Conversion factor from engineering u
# HIERARCH ESO INS TILT1 ENG2MRADX = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS TILT1 ENG2MRADY = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS TILT1 ID = 'iops1   ' / FS/PS id.
# HIERARCH ESO INS TILT1 MODE = 'REF     ' / Device mode.
# HIERARCH ESO INS TILT1 NAME = 'I/O Pupil stabil 1' / Device description.
# HIERARCH ESO INS TILT1 VAL1 = 12717. / Piezo axis  numeric value.
# HIERARCH ESO INS TILT1 VAL2 = 25558. / Piezo axis  numeric value.
# HIERARCH ESO INS TILT2 ENG2ARCX = 0.00022 / Conversion factor from engineering u
# HIERARCH ESO INS TILT2 ENG2ARCY = 0.00016 / Conversion factor from engineering u
# HIERARCH ESO INS TILT2 ENG2MRADX = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS TILT2 ENG2MRADY = 0.0004 / Conversion factor from engineering
# HIERARCH ESO INS TILT2 ID = 'iofs1   ' / FS/PS id.
# HIERARCH ESO INS TILT2 MODE = 'AUTO    ' / Device mode.
# HIERARCH ESO INS TILT2 NAME = 'I/O Field stabil 1' / Device description.
# HIERARCH ESO INS TILT2 VAL1 = 16777. / Piezo axis  numeric value.
# HIERARCH ESO INS TILT2 VAL2 = 14763. / Piezo axis  numeric value.
# HIERARCH ESO INS5 DID1 = 'ICS5_ICS-328527' / Data dictionary for INS.
# HIERARCH ESO INS5 DID2 = 'PRIMARY-FITS-1.2' / Data dictionary for INS.
# HIERARCH ESO INS5 FESELA ENC = 310801 / [Enc] Absolute position.
# HIERARCH ESO INS5 FESELA ID = '1       ' / Unique ID.
# HIERARCH ESO INS5 FESELA NAME = 'FE1_LD  ' / Name.
# HIERARCH ESO INS5 FESELA NO = 1 / Slot number.
# HIERARCH ESO INS5 FESELA POS = 155.4005 / [mm] Component position.
# HIERARCH ESO INS5 FESELA TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 FESELB ENC = 69245 / [Enc] Absolute position.
# HIERARCH ESO INS5 FESELB ID = '17      ' / Unique ID.
# HIERARCH ESO INS5 FESELB NAME = 'FE1_FP  ' / Name.
# HIERARCH ESO INS5 FESELB NO = 17 / Slot number.
# HIERARCH ESO INS5 FESELB POS = 34.6225 / [mm] Component position.
# HIERARCH ESO INS5 FESELB TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 FILT2 ENC = 117778 / [Enc] EM Filter wheel absolute position.
# HIERARCH ESO INS5 FILT2 ID = 'ND1_ID  ' / EM Filter unique id.
# HIERARCH ESO INS5 FILT2 NAME = 'EMND00  ' / EM Filter name.
# HIERARCH ESO INS5 FILT2 NO = 1 / EM Filter wheel position index.
# HIERARCH ESO INS5 FILT2 POS = 180. / [deg] Component position.
# HIERARCH ESO INS5 FILT2 TYPE = 'FREE    ' / Element.
# HIERARCH ESO INS5 ID = 'ESPRESSO/ICS5' / Instrument ID.
# HIERARCH ESO INS5 LAMP4 FREQ = 18000000000. / [Hz] Absolute frequency
# HIERARCH ESO INS5 LAMP4 FREQOFFS = 270000000. / [Hz] Offset of first comb
# HIERARCH ESO INS5 LAMP4 ID = 'LFC1    ' / LFC instance ID
# HIERARCH ESO INS5 LAMP4 LEVEL = 0. / Level
# HIERARCH ESO INS5 LAMP4 NAME = 'LFC red ' / LFC instance name
# HIERARCH ESO INS5 LAMP4 STABLE = F / Light OK since reset
# HIERARCH ESO INS5 LAMP4 STAT = 'OFF     ' / Status of LFC
# HIERARCH ESO INS5 LAMP4 SWSIM = T / If T, function is software simulated.
# HIERARCH ESO INS5 LAMP5 ID = 'FPCS    ' / Lamp ID.
# HIERARCH ESO INS5 LAMP5 NAME = 'FPCS_Lamp' / Lamp name.
# HIERARCH ESO INS5 LAMP5 ST = T / Lamp activated.
# HIERARCH ESO INS5 LAMP5 STAT = 'ON      ' / Lamp activated.
# HIERARCH ESO INS5 LAMP5 TIME = 7767. / Time [sec] lamp was on.
# HIERARCH ESO INS5 LSELA ENC = 152001 / [Enc] Absolute position.
# HIERARCH ESO INS5 LSELA ID = '7       ' / Unique ID.
# HIERARCH ESO INS5 LSELA NAME = 'DARK    ' / Name.
# HIERARCH ESO INS5 LSELA NO = 7 / Slot number.
# HIERARCH ESO INS5 LSELA POS = 76.0005 / [mm] Component position.
# HIERARCH ESO INS5 LSELA TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 LSELB ENC = 152013 / [Enc] Absolute position.
# HIERARCH ESO INS5 LSELB ID = '7       ' / Unique ID.
# HIERARCH ESO INS5 LSELB NAME = 'DARK    ' / Name.
# HIERARCH ESO INS5 LSELB NO = 7 / Slot number.
# HIERARCH ESO INS5 LSELB POS = 76.0065 / [mm] Component position.
# HIERARCH ESO INS5 LSELB TYPE = 'MASK    ' / Element.
# HIERARCH ESO INS5 MODSEL ENC = 642231 / [Enc] Component absolute position.
# HIERARCH ESO INS5 MODSEL ID = 'UT1HR   ' / Unique ID.
# HIERARCH ESO INS5 MODSEL NAME = 'UT1HR   ' / MODSEL name.
# HIERARCH ESO INS5 MODSEL NO = 2 / MODSEL slot number.
# HIERARCH ESO INS5 MODSEL POS = 64.2231 / [deg] Component position.
# HIERARCH ESO INS5 MODSEL TYPE = 'MASK    ' / MODSEL element.
# HIERARCH ESO INS5 PATH = '        ' / Optical path used.
# HIERARCH ESO INS5 PRES100 VAL = 7.985E-06 / [mbar] Blue cryostat pressure.
# HIERARCH ESO INS5 PRES101 VAL = 5.34E-06 / [mbar] Red cryostat pressure.
# HIERARCH ESO INS5 PRES102 VAL = 0. / [mbar] Cryopump1 cryostat pressure.
# HIERARCH ESO INS5 PRES103 VAL = 290.6 / [mbar] Cryopump2 cryostat pressure.
# HIERARCH ESO INS5 PRES104 VAL = 1.422E-06 / [mbar] Manifold vacuum pressure.
# HIERARCH ESO INS5 PRES105 VAL = 6.085E-05 / [mbar] Pre vacuum pressure.
# HIERARCH ESO INS5 PRES106 VAL = 5.215E-07 / [mbar] Vessel vacuum pressure.
# HIERARCH ESO INS5 PRES107 VAL = 4.476E-06 / [mbar] Fabry-Perot vacuum pressure.
# HIERARCH ESO INS5 SENS1 VAL = 12.9 / [%] VV regulator heater output.
# HIERARCH ESO INS5 SENS101 VAL = 96.931107 / [K] Blue cryostat cold plate temp.
# HIERARCH ESO INS5 SENS109 VAL = 95.653435 / [K] Red cryostat cold plate temp.
# HIERARCH ESO INS5 SENS150 VAL = 64. / [%] Blue detector mount heat.
# HIERARCH ESO INS5 SENS151 VAL = 4.455387 / [%] Blue detector table heater.
# HIERARCH ESO INS5 SENS152 VAL = 59.200001 / [%] Red detector mount heat.
# HIERARCH ESO INS5 SENS153 VAL = 0. / [%] Red detector table heater.
# HIERARCH ESO INS5 SENS154 VAL = 4.0E-06 / [%] Blue detector front flange heater
# HIERARCH ESO INS5 SENS155 VAL = 4.0E-06 / [%] Red detector front flange heater.
# HIERARCH ESO INS5 SENS2 VAL = 2.7 / [%] FP regulator heater output.
# HIERARCH ESO INS5 SENSOR1 ID = 'topt    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR1 NAME = 'Optical components (Lake 218)' / Sensor device
# HIERARCH ESO INS5 SENSOR10 ID = 'cab3    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR10 NAME = 'Thermal Cabinet cooling controller' / Sensor
# HIERARCH ESO INS5 SENSOR11 ID = 'dis1    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR11 NAME = 'Digital signals 1' / Sensor device common nam
# HIERARCH ESO INS5 SENSOR12 ID = 'dis2    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR12 NAME = 'Digital signals 2' / Sensor device common nam
# HIERARCH ESO INS5 SENSOR13 ID = 'alpiq   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR13 NAME = '2T enclosure sensors' / Sensor device common
# HIERARCH ESO INS5 SENSOR14 ID = 'tencl   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR14 NAME = 'Housekeeping (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR15 ID = 'cryohf  ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR15 NAME = 'VCS system high-freq samp' / Sensor device co
# HIERARCH ESO INS5 SENSOR16 ID = 'vccc    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR16 NAME = 'Vacuum Cabinet Cooling Controller' / Sensor d
# HIERARCH ESO INS5 SENSOR2 ID = 'tbenc   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR2 NAME = 'Optical bench (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR3 ID = 'tvv     ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR3 NAME = 'Vacuum Vessel (Lake 218)' / Sensor device comm
# HIERARCH ESO INS5 SENSOR4 ID = 'regvv   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR4 NAME = 'Lakeshore 336' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR5 ID = 'reg3T   ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR5 NAME = 'Lakeshore 336' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR6 ID = 'cryo    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR6 NAME = 'VCS system' / Sensor device common name.
# HIERARCH ESO INS5 SENSOR7 ID = 'tfe     ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR7 NAME = 'FEs temperature sensors' / Sensor device commo
# HIERARCH ESO INS5 SENSOR8 ID = 'cab1    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR8 NAME = 'Main Cabinet cooling controller' / Sensor devi
# HIERARCH ESO INS5 SENSOR9 ID = 'cab2    ' / Sensor device unique id.
# HIERARCH ESO INS5 SENSOR9 NAME = 'Calibration Cabinet cooling controller' / Sens
# HIERARCH ESO INS5 SHUSEL CFG = 'HR      ' / Device configuration.
# HIERARCH ESO INS5 SHUSEL ID = 'shusel  ' / Unique ID.
# HIERARCH ESO INS5 SHUSEL MODE = 'OPER    ' / Device mode.
# HIERARCH ESO INS5 SHUSEL NAME = 'Shutter selector' / Name.
# HIERARCH ESO INS5 SHUSEL ST = 'CLOSED  ' / Device status.
# HIERARCH ESO INS5 SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS5 TEMP1 VAL = 18.77 / [C] Main collimator.
# HIERARCH ESO INS5 TEMP10 VAL = 18.669 / [C] Near echelle grating.
# HIERARCH ESO INS5 TEMP100 VAL = 97.536301 / [K] Blue cryostat sorption pump temp
# HIERARCH ESO INS5 TEMP101 VAL = 19. / [C] Blue front flange temp.
# HIERARCH ESO INS5 TEMP102 VAL = 99.714294 / [K] Red cryostat sorption pump temp.
# HIERARCH ESO INS5 TEMP103 VAL = 19. / [C] Red front flange temp.
# HIERARCH ESO INS5 TEMP104 VAL = 0. / [K] Cryopump1 cold plate temp.
# HIERARCH ESO INS5 TEMP105 VAL = 0. / [K] Cryopump1 sorption pump temp.
# HIERARCH ESO INS5 TEMP106 VAL = 0. / [K] Cryopump1 2nd stage temp.
# HIERARCH ESO INS5 TEMP107 VAL = 0. / [K] Cryopump2 cold plate temp.
# HIERARCH ESO INS5 TEMP108 VAL = 0. / [K] Cryopump2 sorption pump temp.
# HIERARCH ESO INS5 TEMP109 VAL = 0. / [K] Cryopump2 2nd stage temp.
# HIERARCH ESO INS5 TEMP11 VAL = 18.522 / [C] Near red camera.
# HIERARCH ESO INS5 TEMP12 VAL = 18.6 / [C] Near blue camera.
# HIERARCH ESO INS5 TEMP13 VAL = 18.572 / [C] Optical bench feet 1.
# HIERARCH ESO INS5 TEMP14 VAL = 18.586 / [C] Optical bench feet 2.
# HIERARCH ESO INS5 TEMP15 VAL = 18.637 / [C] Optical bench feet 3.
# HIERARCH ESO INS5 TEMP150 VAL = 148.003006 / [K] Blue detector mount temp.
# HIERARCH ESO INS5 TEMP151 VAL = 155.014999 / [K] Blue detector package temp.
# HIERARCH ESO INS5 TEMP152 VAL = 146.509171 / [K] Blue detector table temp.
# HIERARCH ESO INS5 TEMP153 VAL = 147.522995 / [K] Red detector mount temp.
# HIERARCH ESO INS5 TEMP154 VAL = 156.660004 / [K] Red detector package temp.
# HIERARCH ESO INS5 TEMP155 VAL = 147.419006 / [K] Red detector table temp.
# HIERARCH ESO INS5 TEMP16 VAL = 18.572 / [C] Pupil slicer.
# HIERARCH ESO INS5 TEMP17 VAL = 18.659 / [C] Shield 1.
# HIERARCH ESO INS5 TEMP18 VAL = 18.71 / [C] Shield 2.
# HIERARCH ESO INS5 TEMP2 VAL = 18.673 / [C] Echelle grating.
# HIERARCH ESO INS5 TEMP25 VAL = 19.443 / [C] 3T up.
# HIERARCH ESO INS5 TEMP26 VAL = 18.725 / [C] 3T down.
# HIERARCH ESO INS5 TEMP29 VAL = 16.651 / [C] 2T env 1.
# HIERARCH ESO INS5 TEMP3 VAL = 18.652 / [C] Cross disperser blue.
# HIERARCH ESO INS5 TEMP30 VAL = 16.649 / [C] 2T env 2.
# HIERARCH ESO INS5 TEMP31 VAL = 12.831 / [C] 1T env 1.
# HIERARCH ESO INS5 TEMP32 VAL = 13.569 / [C] 1T env 2.
# HIERARCH ESO INS5 TEMP33 REF = 19. / Temperature sensor reference value [C].
# HIERARCH ESO INS5 TEMP33 VAL = 19.001 / [C] VV feet T-sensor primary.
# HIERARCH ESO INS5 TEMP34 VAL = 18.938 / [C] VV feet T-sensor secondary.
# HIERARCH ESO INS5 TEMP35 VAL = 24.745 / [C] FP T-sensor secondary.
# HIERARCH ESO INS5 TEMP36 REF = 25. / [C] FP T-setpoint.
# HIERARCH ESO INS5 TEMP36 VAL = 25. / [C] FP T-sensor primary.
# HIERARCH ESO INS5 TEMP37 REF = 19. / [C] 3T T-setpoint.
# HIERARCH ESO INS5 TEMP37 VAL = 19. / [C] 3T T-sensor primary.
# HIERARCH ESO INS5 TEMP38 VAL = 19.19 / [C] 3T T-sensor secondary.
# HIERARCH ESO INS5 TEMP4 VAL = 18.646 / [C] Cross disperser red.
# HIERARCH ESO INS5 TEMP41 VAL = 12.3 / [C] FE1 Bench bottom.
# HIERARCH ESO INS5 TEMP42 VAL = 12.1 / [C] FE1 Bench top.
# HIERARCH ESO INS5 TEMP43 VAL = 11.2 / [C] FE1 TCCD field.
# HIERARCH ESO INS5 TEMP44 VAL = 11.1 / [C] FE1 TCCD pupil.
# HIERARCH ESO INS5 TEMP47 VAL = 12.2 / [C] FE2 Bench bottom.
# HIERARCH ESO INS5 TEMP48 VAL = 12.4 / [C] FE2 Bench top.
# HIERARCH ESO INS5 TEMP49 VAL = 11. / [C] FE2 TCCD field.
# HIERARCH ESO INS5 TEMP5 VAL = 18.652 / [C] Dichroic.
# HIERARCH ESO INS5 TEMP50 VAL = 14.6 / [C] FE2 TCCD pupil.
# HIERARCH ESO INS5 TEMP53 VAL = 12.1 / [C] FE3 Bench bottom.
# HIERARCH ESO INS5 TEMP54 VAL = 12.1 / [C] FE3 Bench top.
# HIERARCH ESO INS5 TEMP55 VAL = 10.2 / [C] FE3 TCCD field.
# HIERARCH ESO INS5 TEMP56 VAL = 10.5 / [C] FE3 TCCD pupil.
# HIERARCH ESO INS5 TEMP59 VAL = 9.2 / [C] FE4 Bench bottom.
# HIERARCH ESO INS5 TEMP6 VAL = 18.727 / [C] Field mirror.
# HIERARCH ESO INS5 TEMP60 VAL = 12.4 / [C] FE4 Bench top.
# HIERARCH ESO INS5 TEMP61 VAL = 11.3 / [C] FE4 TCCD field.
# HIERARCH ESO INS5 TEMP62 VAL = 11.2 / [C] FE4 TCCD pupil.
# HIERARCH ESO INS5 TEMP65 VAL = 11.8 / [C] Spectro Bench EM.
# HIERARCH ESO INS5 TEMP66 VAL = 11.5 / [C] Spectro TCCD EM.
# HIERARCH ESO INS5 TEMP7 VAL = 18.568 / [C] Transfer coll. blue.
# HIERARCH ESO INS5 TEMP8 VAL = 18.518 / [C] Transfer coll. red.
# HIERARCH ESO INS5 TEMP83 VAL = 14.296 / [C] Calibration unit cabinet ambinet
# HIERARCH ESO INS5 TEMP9 VAL = 18.714 / [C] Near main collimator.
# HIERARCH ESO INS5 VFILT1 DEN = 0.91 / [D] Position.
# HIERARCH ESO INS5 VFILT1 ENC = 112478 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT1 ID = 'ndfila1 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT1 NAME = 'Var ND filter cal A wheel 1' / Variable density
# HIERARCH ESO INS5 VFILT1 POS = 171.9 / [deg] Position.
# HIERARCH ESO INS5 VFILT2 DEN = 0.91 / [D] Position.
# HIERARCH ESO INS5 VFILT2 ENC = 112478 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT2 ID = 'ndfila2 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT2 NAME = 'Var ND filter CAL A wheel 2' / Variable density
# HIERARCH ESO INS5 VFILT2 POS = 171.9 / [deg] Position.
# HIERARCH ESO INS5 VFILT3 DEN = 1.44 / [D] Position.
# HIERARCH ESO INS5 VFILT3 ENC = 143689 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT3 ID = 'ndfilb1 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT3 NAME = 'Var ND filter CAL B wheel 1' / Variable density
# HIERARCH ESO INS5 VFILT3 POS = 219.5998 / [deg] Position.
# HIERARCH ESO INS5 VFILT4 DEN = 1.44 / [D] Position.
# HIERARCH ESO INS5 VFILT4 ENC = 143689 / [Enc] Absolute position.
# HIERARCH ESO INS5 VFILT4 ID = 'ndfilb2 ' / Device unique ID.
# HIERARCH ESO INS5 VFILT4 NAME = 'Var ND filter CAL B wheel 2' / Variable density
# HIERARCH ESO INS5 VFILT4 POS = 219.5998 / [deg] Position.
# HIERARCH ESO DET BINX =      2 / Setup binning factor along X
# HIERARCH ESO DET BINY =      1 / Setup binning factor along Y
# HIERARCH ESO DET CHIPS =     2 / Number of chips in the mosaic
# HIERARCH ESO DET CON PWIPE = T / Periodic wipe
# HIERARCH ESO DET DEV1 BOARD1 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD1 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD1 SERNO = '000013A6E838' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD1 TRANS = '0000163DF28F' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD1 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD1 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD2 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD2 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD2 SERNO = '000011AA6C53' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD2 TRANS = '0000163DFF54' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD2 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD2 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD3 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD3 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD3 SERNO = '00001458856D' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD3 TRANS = '0000163DEBE4' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD3 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD3 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 BOARD4 BCKPL = '000010805281' / Serial no (backplane)
# HIERARCH ESO DET DEV1 BOARD4 REV = '5.6.4   ' / Revision
# HIERARCH ESO DET DEV1 BOARD4 SERNO = '000013A6DAE3' / Serial no (board)
# HIERARCH ESO DET DEV1 BOARD4 TRANS = '0000163DD7F8' / Serial no (transition boar
# HIERARCH ESO DET DEV1 BOARD4 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV1 BOARD4 VERSION = 1 / Version
# HIERARCH ESO DET DEV1 CHIPS = 1 / Number of chips in the mosaic
# HIERARCH ESO DET DEV1 EXP RDTTIME = 37.346 / [s] Image readout time
# HIERARCH ESO DET DEV1 EXP XFERTIM = 37.314 / [s] Image transfer time
# HIERARCH ESO DET DEV1 ID = 'ESPRESSO-BLUE' / Detector system Id
# HIERARCH ESO DET DEV1 OUTPUTS = 16 / Number of outputs
# HIERARCH ESO DET DEV1 REV = '0.4.1   ' / Revision
# HIERARCH ESO DET DEV1 SHUT ID = 'ShEspresso' / Shutter unique identifier
# HIERARCH ESO DET DEV1 SHUT TMCLOS = 0.015 / [s] Time taken to close shutter
# HIERARCH ESO DET DEV1 SHUT TMOPEN = 0.019 / [s] Time taken to open shutter
# HIERARCH ESO DET DEV1 SHUT TYPE = 'Illy    ' / Shutter type
# HIERARCH ESO DET DEV1 SOFW BASE = '322630  ' / Base software version
# HIERARCH ESO DET DEV1 SOFW DETMOD = '315314  ' / Detector module revision
# HIERARCH ESO DET DEV1 SOFW MODE = 'NORMAL  ' / Software operational mode
# HIERARCH ESO DET DEV1 SOFW OPT = '322630  ' / Optical software version
# HIERARCH ESO DET DEV2 BOARD1 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD1 SERNO = '000014587F6F' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD1 TRANS = '0000163E0D9B' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD1 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD1 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD2 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD2 SERNO = '0000163DBCC3' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD2 TRANS = '0000163DA9FA' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD2 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD2 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD3 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD3 SERNO = '0000163DECA8' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD3 TRANS = '0000163DAACD' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD3 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD3 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 BOARD4 BCKPL = '00001080525C' / Serial no (backplane)
# HIERARCH ESO DET DEV2 BOARD4 SERNO = '0000163DA5E4' / Serial no (board)
# HIERARCH ESO DET DEV2 BOARD4 TRANS = '00001216DA39' / Serial no (transition boar
# HIERARCH ESO DET DEV2 BOARD4 TYPE = 'FEB     ' / Type
# HIERARCH ESO DET DEV2 BOARD4 VERSION = 1 / Version
# HIERARCH ESO DET DEV2 CHIPS = 1 / Number of chips in the mosaic
# HIERARCH ESO DET DEV2 EXP RDTTIME = 37.345 / [s] Image readout time
# HIERARCH ESO DET DEV2 EXP XFERTIM = 37.309 / [s] Image transfer time
# HIERARCH ESO DET DEV2 ID = 'ESPRESSO-RED' / Detector system Id
# HIERARCH ESO DET DEV2 OUTPUTS = 16 / Number of outputs
# HIERARCH ESO DET DEV2 REV = '0.4.1   ' / Revision
# HIERARCH ESO DET DEV2 SHUT ID = 'dummy   ' / Shutter unique identifier
# HIERARCH ESO DET DEV2 SHUT TMCLOS = 0. / [s] Time taken to close shutter
# HIERARCH ESO DET DEV2 SHUT TMOPEN = 0. / [s] Time taken to open shutter
# HIERARCH ESO DET DEV2 SHUT TYPE = 'nostatus' / Shutter type
# HIERARCH ESO DET DEV2 SOFW BASE = '322630  ' / Base software version
# HIERARCH ESO DET DEV2 SOFW DETMOD = '315314  ' / Detector module revision
# HIERARCH ESO DET DEV2 SOFW MODE = 'NORMAL  ' / Software operational mode
# HIERARCH ESO DET DEV2 SOFW OPT = '322630  ' / Optical software version
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.NGCDCS,ESO-VLT-DIC.NGCCON' / Used di
# HIERARCH ESO DET DIT1 =   300. / [s] Actual subintegration time
# HIERARCH ESO DET DKTM =   300. / [s] Dark current time
# HIERARCH ESO DET EXP NO =   32 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET NAME = 'ESPRESSO-BLUE' / Name of detector system
# HIERARCH ESO DET NDIT =      1 / Number of Sub-Integrations
# HIERARCH ESO DET OUTPUTS =  32 / Number of outputs
# HIERARCH ESO DET READ CURID = 8 / Used readout mode id
# HIERARCH ESO DET READ CURNAME = 'Slow    ' / Used readout mode name
# HIERARCH ESO DET UIT1 =   300. / [s] User defined subintegration ti
# HIERARCH ESO PRO CATG = 'CCF_SKYSUB_A' / Category of pipeline product frame
# HIERARCH ESO PRO ANCESTOR = 'ESPRE.2021-08-11T00:51:07.338.fits'
# HIERARCH ESO PRO DID = 'PRO-1.16' / Data dictionary for PRO
# HIERARCH ESO PRO TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO SCIENCE =   T / Scientific product if T
# HIERARCH ESO PRO REC1 ID = 'espdr_sci_red' / Pipeline recipe (unique) identifier
# HIERARCH ESO PRO REC1 DRS ID = 'cpl-7.1.3' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID = 'espdr/2.3.1' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME = 'ESPRE.2021-08-11T00:51:07.338.fits' / File na
# HIERARCH ESO PRO REC1 RAW1 CATG = 'OBJ_SKY ' / Category of raw frame
# HIERARCH ESO PRO DATANCOM =  1 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME = 'ESPRESSO_2x1_CCD_geom_config.fits' / File nam
# HIERARCH ESO PRO REC1 CAL1 CATG = 'CCD_GEOM' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL2 NAME= 'ESPRESSO_SINGLEHR_2x1_master_inst_config_2018'
# HIERARCH ESO PRO REC1 CAL2 CATG = 'MASTER_INST_CONFIG' / Category of calibration
# HIERARCH ESO PRO REC1 CAL3 NAME= 'r.ESPRE.2021-08-11T08:53:22.388_MASTER_BIAS_R'
# HIERARCH ESO PRO REC1 CAL3 CATG = 'MASTER_BIAS_RES' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL3 DATAMD5 = 'e81c096098d947342e8917c2dfbb15d0' / MD5 si
# HIERARCH ESO PRO REC1 CAL4 NAME= 'r.ESPRE.2021-07-22T20:04:24.709_HOT_PIXEL_MAS'
# HIERARCH ESO PRO REC1 CAL4 CATG = 'HOT_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL4 DATAMD5 = 'e4e5f405f535c014a491cb6f58c4fcea' / MD5 si
# HIERARCH ESO PRO REC1 CAL5 NAME= 'r.ESPRE.2021-02-23T13:36:11.301_BAD_PIXEL_MAS'
# HIERARCH ESO PRO REC1 CAL5 CATG = 'BAD_PIXEL_MASK' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL5 DATAMD5 = '0540d6353ed3326c7d7cf8bab18838de' / MD5 si
# HIERARCH ESO PRO REC1 CAL6 NAME= 'r.ESPRE.2021-08-11T09:04:42.594_ORDER_TABLE_A'
# HIERARCH ESO PRO REC1 CAL6 CATG = 'ORDER_TABLE_A' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL6 DATAMD5 = '7d52200bd7da4b0a5285925b606af60a' / MD5 si
# HIERARCH ESO PRO REC1 CAL7 NAME= 'r.ESPRE.2021-08-11T09:04:42.594_ORDER_TABLE_B'
# HIERARCH ESO PRO REC1 CAL7 CATG = 'ORDER_TABLE_B' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL7 DATAMD5 = '5f3e9eae6117b5a819b269e74bf9f9ef' / MD5 si
# HIERARCH ESO PRO REC1 CAL8 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_ORDER_PROFILE'
# HIERARCH ESO PRO REC1 CAL8 CATG = 'ORDER_PROFILE_A' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL8 DATAMD5 = '83b8f87d7c80df11e65204e77efa823d' / MD5 si
# HIERARCH ESO PRO REC1 CAL9 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_ORDER_PROFILE'
# HIERARCH ESO PRO REC1 CAL9 CATG = 'ORDER_PROFILE_B' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL9 DATAMD5 = 'e9492ff601beba5851c0b1fc6d4937c8' / MD5 si
# HIERARCH ESO PRO REC1 CAL10 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_FSPECTRUM_A.'
# HIERARCH ESO PRO REC1 CAL10 CATG = 'FSPECTRUM_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL10 DATAMD5 = 'aa1dc08c93a3d4ef1fa8011874f24870' / MD5 s
# HIERARCH ESO PRO REC1 CAL11 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_FSPECTRUM_B.'
# HIERARCH ESO PRO REC1 CAL11 CATG = 'FSPECTRUM_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL11 DATAMD5 = 'f2c25e46e33c8f234ce683a8872ed4cd' / MD5 s
# HIERARCH ESO PRO REC1 CAL12 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_BLAZE_A.fits'
# HIERARCH ESO PRO REC1 CAL12 CATG = 'BLAZE_A ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL12 DATAMD5 = '92f38048d948fe2cc390c137f5dbb9e3' / MD5 s
# HIERARCH ESO PRO REC1 CAL13 NAME= 'r.ESPRE.2021-08-11T09:07:32.332_BLAZE_B.fits'
# HIERARCH ESO PRO REC1 CAL13 CATG = 'BLAZE_B ' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL13 DATAMD5 = '572a598b54e170769c2c69a7c3f42ff3' / MD5 s
# HIERARCH ESO PRO REC1 CAL14 NAME= 'r.ESPRE.2021-08-11T09:40:03.925_WAVE_MATRIX_'
# HIERARCH ESO PRO REC1 CAL14 CATG = 'WAVE_MATRIX_THAR_FP_A' / Category of calibra
# HIERARCH ESO PRO REC1 CAL14 DATAMD5 = '7af19ecdd603ec0a3424309a2624ccdb' / MD5 s
# HIERARCH ESO PRO REC1 CAL15 NAME= 'r.ESPRE.2021-08-11T09:42:03.884_WAVE_MATRIX_'
# HIERARCH ESO PRO REC1 CAL15 CATG = 'WAVE_MATRIX_FP_THAR_B' / Category of calibra
# HIERARCH ESO PRO REC1 CAL15 DATAMD5 = 'd92f6327d98c22d2130b0856f9df26ac' / MD5 s
# HIERARCH ESO PRO REC1 CAL16 NAME= 'r.ESPRE.2021-08-11T09:40:03.925_DLL_MATRIX_T'
# HIERARCH ESO PRO REC1 CAL16 CATG = 'DLL_MATRIX_THAR_FP_A' / Category of calibrat
# HIERARCH ESO PRO REC1 CAL16 DATAMD5 = 'e0594131f7e2eac7f536fa0f4a7171da' / MD5 s
# HIERARCH ESO PRO REC1 CAL17 NAME= 'r.ESPRE.2021-08-11T09:42:03.884_DLL_MATRIX_F'
# HIERARCH ESO PRO REC1 CAL17 CATG = 'DLL_MATRIX_FP_THAR_B' / Category of calibrat
# HIERARCH ESO PRO REC1 CAL17 DATAMD5 = 'd88e4e00e468a0e3ace0698f63df2439' / MD5 s
# HIERARCH ESO PRO REC1 CAL18 NAME= 'r.ESPRE.2021-08-10T21:57:27.877_REL_EFF_B.fi'
# HIERARCH ESO PRO REC1 CAL18 CATG = 'REL_EFF_B' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL18 DATAMD5 = '69217da47b7ba112fbaad3baf71ce10a' / MD5 s
# HIERARCH ESO PRO REC1 CAL19 NAME= 'r.ESPRE.2021-08-02T00:07:28.505_ABS_EFF_A.fi'
# HIERARCH ESO PRO REC1 CAL19 CATG = 'ABS_EFF_A' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL19 DATAMD5 = '6ad1905e05227fa71ddf49e99a339c4a' / MD5 s
# HIERARCH ESO PRO REC1 CAL20 NAME = 'ESPRESSO_EXTINCTION_TABLE.fits' / File name
# HIERARCH ESO PRO REC1 CAL20 CATG = 'EXT_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL21 NAME = 'ESPRESSO_mask_lut.fits' / File name of calib
# HIERARCH ESO PRO REC1 CAL21 CATG = 'MASK_LUT' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL22 NAME = 'ESPRESSO_SINGLEHR_2x1_FLUX_TEMPLATE.fits'
# HIERARCH ESO PRO REC1 CAL22 CATG = 'FLUX_TEMPLATE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL23 NAME = 'ESPRESSO_F9.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL23 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL24 NAME = 'ESPRESSO_G2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL24 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL25 NAME = 'ESPRESSO_G8.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL25 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL26 NAME = 'ESPRESSO_G9.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL26 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL27 NAME = 'ESPRESSO_K2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL27 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL28 NAME = 'ESPRESSO_K6.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL28 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL29 NAME = 'ESPRESSO_M0.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL29 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL30 NAME = 'ESPRESSO_M2.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL30 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL31 NAME = 'ESPRESSO_M3.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL31 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL32 NAME = 'ESPRESSO_M4.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL32 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL33 NAME = 'ESPRESSO_M5.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL33 CATG = 'MASK_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 PARAM1 NAME = 'ovsc_sig_clip_method' / method for sigma cl
# HIERARCH ESO PRO REC1 PARAM1 VALUE = 'mean    ' / Default: 'mean'
# HIERARCH ESO PRO REC1 PARAM2 NAME = 'ovsc_ksigma' / ksigma for sigma clipping in
# HIERARCH ESO PRO REC1 PARAM2 VALUE = '4       ' / Default: 4
# HIERARCH ESO PRO REC1 PARAM3 NAME = 'ovsc_max_iter' / maximal number of iteratio
# HIERARCH ESO PRO REC1 PARAM3 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO REC1 PARAM4 NAME = 'background_sw' / Background subtraction act
# HIERARCH ESO PRO REC1 PARAM4 VALUE = 'off     ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM5 NAME = 'sci_bkgr_grid_size_x' / Grid size in x used
# HIERARCH ESO PRO REC1 PARAM5 VALUE = '577     ' / Default: 577
# HIERARCH ESO PRO REC1 PARAM6 NAME = 'sci_bkgr_grid_size_y' / Grid size in y used
# HIERARCH ESO PRO REC1 PARAM6 VALUE = '256     ' / Default: 256
# HIERARCH ESO PRO REC1 PARAM7 NAME = 'wave_cal_source' / Wavelength calibration s
# HIERARCH ESO PRO REC1 PARAM7 VALUE = 'THAR    ' / Default: 'THAR'
# HIERARCH ESO PRO REC1 PARAM8 NAME = 'mask_table_id' / Mask table to be used, def
# HIERARCH ESO PRO REC1 PARAM8 VALUE = 'K2      ' / Default: 'XX'
# HIERARCH ESO PRO REC1 PARAM9 NAME = 'rv_center' / Approximate RV. In case of def
# HIERARCH ESO PRO REC1 PARAM9 VALUE = '-2      ' / Default: -9999
# HIERARCH ESO PRO REC1 PARAM10 NAME = 'rv_range' / Range for the RV table.
# HIERARCH ESO PRO REC1 PARAM10 VALUE = '20      ' / Default: 20
# HIERARCH ESO PRO REC1 PARAM11 NAME = 'rv_step ' / Range's step for the RV table.
# HIERARCH ESO PRO REC1 PARAM11 VALUE = '0.5     ' / Default: 0.5
# HIERARCH ESO PRO REC1 PARAM12 NAME = 'extraction_method' / Method used to extrac
# HIERARCH ESO PRO REC1 PARAM12 VALUE = 'horne   ' / Default: 'horne'
# HIERARCH ESO PRO REC1 PARAM13 NAME = 'ksigma_cosmic' / ksigma for removing cosmi
# HIERARCH ESO PRO REC1 PARAM13 VALUE = '3.5     ' / Default: 3.5
# HIERARCH ESO PRO REC1 PARAM14 NAME = 'bias_res_removal_sw' / Flag indicating to
# HIERARCH ESO PRO REC1 PARAM14 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM15 NAME = 'flux_correction_type' / Flux correction: N
# HIERARCH ESO PRO REC1 PARAM15 VALUE = 'AUTO    ' / Default: 'AUTO'
# HIERARCH ESO PRO REC1 PARAM16 NAME = 'drift_correction_sw' / Drift correction ac
# HIERARCH ESO PRO REC1 PARAM16 VALUE = 'on      ' / Default: 'on'
# HIERARCH ESO PRO REC1 PARAM17 NAME = 'drift_method_fp' / Method adopted to compu
# HIERARCH ESO PRO REC1 PARAM17 VALUE = 'flux_global_drift_global_sequential_fit'
# HIERARCH ESO PRO REC1 PARAM18 NAME = 'drift_space' / Space to compute drift (pix
# HIERARCH ESO PRO REC1 PARAM18 VALUE = 'pixel   ' / Default: 'pixel'
# HIERARCH ESO PRO REC1 PARAM19 NAME = 'drift_ksigma' / ksigma for computing drift
# HIERARCH ESO PRO REC1 PARAM19 VALUE = '50      ' / Default: 50
# HIERARCH ESO PRO REC1 PARAM20 NAME = 'sky_sub_method' / Method used to subtract
# HIERARCH ESO PRO REC1 PARAM20 VALUE = 'pixel-by-pixel' / Default: 'pixel-by-pixe
# HIERARCH ESO PRO REC1 PARAM21 NAME = 'sky_sub_sliding_box_size' / Sliding box si
# ...
# HIERARCH ESO QC THAR LAMP OFFSET AR = -9999.9 / TH lamp offset AR [m/s]
# HIERARCH ESO QC THAR LAMP OFFSET AR1 = -9999.9 / TH lamp offset AR1 [m/s]
# HIERARCH ESO QC THAR LAMP OFFSET AR2 = -9999.9 / TH lamp offset AR2 [m/s]
# HIERARCH ESO QC EXT0 BKGR MEAN = -9999.9 / Bkgr mean [e-] in the extension
# HIERARCH ESO QC EXT0 BKGR MIN = -9999.9 / Bkgr min [e-] in the extension
# HIERARCH ESO QC EXT0 BKGR MAX = -9999.9 / Bkgr max [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MEAN = -9999.9 / Bkgr mean [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MIN = -9999.9 / Bkgr min [e-] in the extension
# HIERARCH ESO QC EXT1 BKGR MAX = -9999.9 / Bkgr max [e-] in the extension
# HIERARCH ESO QC ORDER1 FLUX CORR = 0.588323991939326 / Flux corr for the order
# HIERARCH ESO QC ORDER2 FLUX CORR = 0.588327223804249 / Flux corr for the order
# HIERARCH ESO QC ORDER3 FLUX CORR = 0.59733065648669 / Flux corr for the order
# HIERARCH ESO QC ORDER4 FLUX CORR = 0.597334075741976 / Flux corr for the order
# HIERARCH ESO QC ORDER5 FLUX CORR = 0.607320569792158 / Flux corr for the order
# HIERARCH ESO QC ORDER6 FLUX CORR = 0.60732412690745 / Flux corr for the order
# HIERARCH ESO QC ORDER7 FLUX CORR = 0.618200723847629 / Flux corr for the order
# HIERARCH ESO QC ORDER8 FLUX CORR = 0.61820437782719 / Flux corr for the order
# HIERARCH ESO QC ORDER9 FLUX CORR = 0.629878649585059 / Flux corr for the order
# HIERARCH ESO QC ORDER10 FLUX CORR = 0.629882376592924 / Flux corr for the order
# HIERARCH ESO QC ORDER11 FLUX CORR = 0.642262465053427 / Flux corr for the order
# HIERARCH ESO QC ORDER12 FLUX CORR = 0.642266258481953 / Flux corr for the order
# HIERARCH ESO QC ORDER13 FLUX CORR = 0.655261124877242 / Flux corr for the order
# HIERARCH ESO QC ORDER14 FLUX CORR = 0.655264985317665 / Flux corr for the order
# HIERARCH ESO QC ORDER15 FLUX CORR = 0.668784637291665 / Flux corr for the order
# HIERARCH ESO QC ORDER16 FLUX CORR = 0.668788553241534 / Flux corr for the order
# HIERARCH ESO QC ORDER17 FLUX CORR = 0.682744253243811 / Flux corr for the order
# HIERARCH ESO QC ORDER18 FLUX CORR = 0.6827482129343 / Flux corr for the order
# HIERARCH ESO QC ORDER19 FLUX CORR = 0.697052793255125 / Flux corr for the order
# HIERARCH ESO QC ORDER20 FLUX CORR = 0.69705682026899 / Flux corr for the order
# HIERARCH ESO QC ORDER21 FLUX CORR = 0.711624792464384 / Flux corr for the order
# HIERARCH ESO QC ORDER22 FLUX CORR = 0.71162886787247 / Flux corr for the order
# HIERARCH ESO QC ORDER23 FLUX CORR = 0.726376827821085 / Flux corr for the order
# HIERARCH ESO QC ORDER24 FLUX CORR = 0.726380951542509 / Flux corr for the order
# HIERARCH ESO QC ORDER25 FLUX CORR = 0.741227718009156 / Flux corr for the order
# HIERARCH ESO QC ORDER26 FLUX CORR = 0.741231886649601 / Flux corr for the order
# HIERARCH ESO QC ORDER27 FLUX CORR = 0.756098839445656 / Flux corr for the order
# HIERARCH ESO QC ORDER28 FLUX CORR = 0.756103043390482 / Flux corr for the order
# HIERARCH ESO QC ORDER29 FLUX CORR = 0.770914393666772 / Flux corr for the order
# HIERARCH ESO QC ORDER30 FLUX CORR = 0.770918621120217 / Flux corr for the order
# HIERARCH ESO QC ORDER31 FLUX CORR = 0.785601679899102 / Flux corr for the order
# HIERARCH ESO QC ORDER32 FLUX CORR = 0.785605899466404 / Flux corr for the order
# HIERARCH ESO QC ORDER33 FLUX CORR = 0.800091396087325 / Flux corr for the order
# HIERARCH ESO QC ORDER34 FLUX CORR = 0.800095606986531 / Flux corr for the order
# HIERARCH ESO QC ORDER35 FLUX CORR = 0.814317912254197 / Flux corr for the order
# HIERARCH ESO QC ORDER36 FLUX CORR = 0.814322080940869 / Flux corr for the order
# HIERARCH ESO QC ORDER37 FLUX CORR = 0.828219591216381 / Flux corr for the order
# HIERARCH ESO QC ORDER38 FLUX CORR = 0.828223701771137 / Flux corr for the order
# HIERARCH ESO QC ORDER39 FLUX CORR = 0.841739033755033 / Flux corr for the order
# HIERARCH ESO QC ORDER40 FLUX CORR = 0.841743063469579 / Flux corr for the order
# HIERARCH ESO QC ORDER41 FLUX CORR = 0.854823426526394 / Flux corr for the order
# HIERARCH ESO QC ORDER42 FLUX CORR = 0.854827354636328 / Flux corr for the order
# HIERARCH ESO QC ORDER43 FLUX CORR = 0.867424796278044 / Flux corr for the order
# HIERARCH ESO QC ORDER44 FLUX CORR = 0.867428601160526 / Flux corr for the order
# HIERARCH ESO QC ORDER45 FLUX CORR = 0.879500301494176 / Flux corr for the order
# HIERARCH ESO QC ORDER46 FLUX CORR = 0.879503965024142 / Flux corr for the order
# HIERARCH ESO QC ORDER47 FLUX CORR = 0.891012567465339 / Flux corr for the order
# HIERARCH ESO QC ORDER48 FLUX CORR = 0.891016074281154 / Flux corr for the order
# HIERARCH ESO QC ORDER49 FLUX CORR = 0.901929893604503 / Flux corr for the order
# HIERARCH ESO QC ORDER50 FLUX CORR = 0.901933215936779 / Flux corr for the order
# HIERARCH ESO QC ORDER51 FLUX CORR = 0.912226532250713 / Flux corr for the order
# HIERARCH ESO QC ORDER52 FLUX CORR = 0.912229666419336 / Flux corr for the order
# HIERARCH ESO QC ORDER53 FLUX CORR = 0.921882966985493 / Flux corr for the order
# HIERARCH ESO QC ORDER54 FLUX CORR = 0.921885897778765 / Flux corr for the order
# HIERARCH ESO QC ORDER55 FLUX CORR = 0.930886079595865 / Flux corr for the order
# HIERARCH ESO QC ORDER56 FLUX CORR = 0.930888794773836 / Flux corr for the order
# HIERARCH ESO QC ORDER57 FLUX CORR = 0.939229406255379 / Flux corr for the order
# HIERARCH ESO QC ORDER58 FLUX CORR = 0.939231902744041 / Flux corr for the order
# HIERARCH ESO QC ORDER59 FLUX CORR = 0.946913282027907 / Flux corr for the order
# HIERARCH ESO QC ORDER60 FLUX CORR = 0.946915554329536 / Flux corr for the order
# HIERARCH ESO QC ORDER61 FLUX CORR = 0.953944991323368 / Flux corr for the order
# HIERARCH ESO QC ORDER62 FLUX CORR = 0.953947044064051 / Flux corr for the order
# HIERARCH ESO QC ORDER63 FLUX CORR = 0.960338897347441 / Flux corr for the order
# HIERARCH ESO QC ORDER64 FLUX CORR = 0.960340730889925 / Flux corr for the order
# HIERARCH ESO QC ORDER65 FLUX CORR = 0.966116476478049 / Flux corr for the order
# HIERARCH ESO QC ORDER66 FLUX CORR = 0.966118103710585 / Flux corr for the order
# HIERARCH ESO QC ORDER67 FLUX CORR = 0.971306371779605 / Flux corr for the order
# HIERARCH ESO QC ORDER68 FLUX CORR = 0.971307803936838 / Flux corr for the order
# HIERARCH ESO QC ORDER69 FLUX CORR = 0.975944330406776 / Flux corr for the order
# HIERARCH ESO QC ORDER70 FLUX CORR = 0.975945579739829 / Flux corr for the order
# HIERARCH ESO QC ORDER71 FLUX CORR = 0.980073118756707 / Flux corr for the order
# HIERARCH ESO QC ORDER72 FLUX CORR = 0.980074200102962 / Flux corr for the order
# HIERARCH ESO QC ORDER73 FLUX CORR = 0.983742385104478 / Flux corr for the order
# HIERARCH ESO QC ORDER74 FLUX CORR = 0.983743318809417 / Flux corr for the order
# HIERARCH ESO QC ORDER75 FLUX CORR = 0.987008404262468 / Flux corr for the order
# HIERARCH ESO QC ORDER76 FLUX CORR = 0.987009210010427 / Flux corr for the order
# HIERARCH ESO QC ORDER77 FLUX CORR = 0.989933781106913 / Flux corr for the order
# HIERARCH ESO QC ORDER78 FLUX CORR = 0.989934479305646 / Flux corr for the order
# HIERARCH ESO QC ORDER79 FLUX CORR = 0.992587062954328 / Flux corr for the order
# HIERARCH ESO QC ORDER80 FLUX CORR = 0.99258767759261 / Flux corr for the order
# HIERARCH ESO QC ORDER81 FLUX CORR = 0.995042242744432 / Flux corr for the order
# HIERARCH ESO QC ORDER82 FLUX CORR = 0.995042796583164 / Flux corr for the order
# HIERARCH ESO QC ORDER83 FLUX CORR = 0.997378181338263 / Flux corr for the order
# HIERARCH ESO QC ORDER84 FLUX CORR = 0.99737869431425 / Flux corr for the order
# HIERARCH ESO QC ORDER85 FLUX CORR = 0.999677904482667 / Flux corr for the order
# HIERARCH ESO QC ORDER86 FLUX CORR = 0.999678399417235 / Flux corr for the order
# HIERARCH ESO QC ORDER87 FLUX CORR = 1.00202781111 / Flux corr for the order
# HIERARCH ESO QC ORDER88 FLUX CORR = 1.00202830783314 / Flux corr for the order
# HIERARCH ESO QC ORDER89 FLUX CORR = 1.00451674498163 / Flux corr for the order
# HIERARCH ESO QC ORDER90 FLUX CORR = 1.00451726226368 / Flux corr for the order
# HIERARCH ESO QC ORDER91 FLUX CORR = 1.00462647168939 / Flux corr for the order
# HIERARCH ESO QC ORDER92 FLUX CORR = 1.00462694859834 / Flux corr for the order
# HIERARCH ESO QC ORDER93 FLUX CORR = 1.0073544739252 / Flux corr for the order
# HIERARCH ESO QC ORDER94 FLUX CORR = 1.00735502821931 / Flux corr for the order
# HIERARCH ESO QC ORDER95 FLUX CORR = 1.01040554700455 / Flux corr for the order
# HIERARCH ESO QC ORDER96 FLUX CORR = 1.0104061442126 / Flux corr for the order
# HIERARCH ESO QC ORDER97 FLUX CORR = 1.01386890474356 / Flux corr for the order
# HIERARCH ESO QC ORDER98 FLUX CORR = 1.0138695476403 / Flux corr for the order
# HIERARCH ESO QC ORDER99 FLUX CORR = 1.01783123824481 / Flux corr for the order
# HIERARCH ESO QC ORDER100 FLUX CORR = 1.0178319456619 / Flux corr for the order
# HIERARCH ESO QC ORDER101 FLUX CORR = 1.02237520691415 / Flux corr for the order
# HIERARCH ESO QC ORDER102 FLUX CORR = 1.02237598270642 / Flux corr for the order
# HIERARCH ESO QC ORDER103 FLUX CORR = 1.02757779045976 / Flux corr for the order
# HIERARCH ESO QC ORDER104 FLUX CORR = 1.02757864616683 / Flux corr for the order
# HIERARCH ESO QC ORDER105 FLUX CORR = 1.03350853483437 / Flux corr for the order
# HIERARCH ESO QC ORDER106 FLUX CORR = 1.03350948194282 / Flux corr for the order
# HIERARCH ESO QC ORDER107 FLUX CORR = 1.04022778381659 / Flux corr for the order
# HIERARCH ESO QC ORDER108 FLUX CORR = 1.04022881901642 / Flux corr for the order
# HIERARCH ESO QC ORDER109 FLUX CORR = 1.04778475894977 / Flux corr for the order
# HIERARCH ESO QC ORDER110 FLUX CORR = 1.04778589961904 / Flux corr for the order
# HIERARCH ESO QC ORDER111 FLUX CORR = 1.05621565984757 / Flux corr for the order
# HIERARCH ESO QC ORDER112 FLUX CORR = 1.05621691138185 / Flux corr for the order
# HIERARCH ESO QC ORDER113 FLUX CORR = 1.06554176348004 / Flux corr for the order
# HIERARCH ESO QC ORDER114 FLUX CORR = 1.06554312137416 / Flux corr for the order
# HIERARCH ESO QC ORDER115 FLUX CORR = 1.07576761939777 / Flux corr for the order
# HIERARCH ESO QC ORDER116 FLUX CORR = 1.07576910307012 / Flux corr for the order
# HIERARCH ESO QC ORDER117 FLUX CORR = 1.08687922176796 / Flux corr for the order
# HIERARCH ESO QC ORDER118 FLUX CORR = 1.08688082367848 / Flux corr for the order
# HIERARCH ESO QC ORDER119 FLUX CORR = 1.0988425535038 / Flux corr for the order
# HIERARCH ESO QC ORDER120 FLUX CORR = 1.09884425347627 / Flux corr for the order
# HIERARCH ESO QC ORDER121 FLUX CORR = 1.11160225006222 / Flux corr for the order
# HIERARCH ESO QC ORDER122 FLUX CORR = 1.11160405639203 / Flux corr for the order
# HIERARCH ESO QC ORDER123 FLUX CORR = 1.12508063162545 / Flux corr for the order
# HIERARCH ESO QC ORDER124 FLUX CORR = 1.12508254639079 / Flux corr for the order
# HIERARCH ESO QC ORDER125 FLUX CORR = 1.13917713189721 / Flux corr for the order
# HIERARCH ESO QC ORDER126 FLUX CORR = 1.13917915316597 / Flux corr for the order
# HIERARCH ESO QC ORDER127 FLUX CORR = 1.15376849209656 / Flux corr for the order
# HIERARCH ESO QC ORDER128 FLUX CORR = 1.15377055669501 / Flux corr for the order
# HIERARCH ESO QC ORDER129 FLUX CORR = 1.16870971834328 / Flux corr for the order
# HIERARCH ESO QC ORDER130 FLUX CORR = 1.16871182667683 / Flux corr for the order
# HIERARCH ESO QC ORDER131 FLUX CORR = 1.1838354882027 / Flux corr for the order
# HIERARCH ESO QC ORDER132 FLUX CORR = 1.1838376242747 / Flux corr for the order
# HIERARCH ESO QC ORDER133 FLUX CORR = 1.19896299831362 / Flux corr for the order
# HIERARCH ESO QC ORDER134 FLUX CORR = 1.19896513357503 / Flux corr for the order
# HIERARCH ESO QC ORDER135 FLUX CORR = 1.21389580380196 / Flux corr for the order
# HIERARCH ESO QC ORDER136 FLUX CORR = 1.21389791427828 / Flux corr for the order
# HIERARCH ESO QC ORDER137 FLUX CORR = 1.22842921240454 / Flux corr for the order
# HIERARCH ESO QC ORDER138 FLUX CORR = 1.22843126188832 / Flux corr for the order
# HIERARCH ESO QC ORDER139 FLUX CORR = 1.24235690955038 / Flux corr for the order
# HIERARCH ESO QC ORDER140 FLUX CORR = 1.24235884553832 / Flux corr for the order
# HIERARCH ESO QC ORDER141 FLUX CORR = 1.25547939814214 / Flux corr for the order
# HIERARCH ESO QC ORDER142 FLUX CORR = 1.25548121371025 / Flux corr for the order
# HIERARCH ESO QC ORDER143 FLUX CORR = 1.26761411247162 / Flux corr for the order
# HIERARCH ESO QC ORDER144 FLUX CORR = 1.26761576710715 / Flux corr for the order
# HIERARCH ESO QC ORDER145 FLUX CORR = 1.27860707624995 / Flux corr for the order
# HIERARCH ESO QC ORDER146 FLUX CORR = 1.27860854270011 / Flux corr for the order
# HIERARCH ESO QC ORDER147 FLUX CORR = 1.28834605165321 / Flux corr for the order
# HIERARCH ESO QC ORDER148 FLUX CORR = 1.2883473316524 / Flux corr for the order
# HIERARCH ESO QC ORDER149 FLUX CORR = 1.29677492883502 / Flux corr for the order
# HIERARCH ESO QC ORDER150 FLUX CORR = 1.29677600550258 / Flux corr for the order
# HIERARCH ESO QC ORDER151 FLUX CORR = 1.30390843622808 / Flux corr for the order
# HIERARCH ESO QC ORDER152 FLUX CORR = 1.30390931364582 / Flux corr for the order
# HIERARCH ESO QC ORDER153 FLUX CORR = 1.3098463317674 / Flux corr for the order
# HIERARCH ESO QC ORDER154 FLUX CORR = 1.30984704107823 / Flux corr for the order
# HIERARCH ESO QC ORDER155 FLUX CORR = 1.31478518385575 / Flux corr for the order
# HIERARCH ESO QC ORDER156 FLUX CORR = 1.31478575828669 / Flux corr for the order
# HIERARCH ESO QC ORDER157 FLUX CORR = 1.31902556893692 / Flux corr for the order
# HIERARCH ESO QC ORDER158 FLUX CORR = 1.31902605594723 / Flux corr for the order
# HIERARCH ESO QC ORDER159 FLUX CORR = 1.32297104297231 / Flux corr for the order
# HIERARCH ESO QC ORDER160 FLUX CORR = 1.32297150060731 / Flux corr for the order
# HIERARCH ESO QC ORDER161 FLUX CORR = 1.3271139678136 / Flux corr for the order
# HIERARCH ESO QC ORDER162 FLUX CORR = 1.32711445511995 / Flux corr for the order
# HIERARCH ESO QC ORDER163 FLUX CORR = 1.33200122545986 / Flux corr for the order
# HIERARCH ESO QC ORDER164 FLUX CORR = 1.33200177698018 / Flux corr for the order
# HIERARCH ESO QC ORDER165 FLUX CORR = 1.33817043464478 / Flux corr for the order
# HIERARCH ESO QC ORDER166 FLUX CORR = 1.33817108311359 / Flux corr for the order
# HIERARCH ESO QC ORDER167 FLUX CORR = 1.34604346706874 / Flux corr for the order
# HIERARCH ESO QC ORDER168 FLUX CORR = 1.34604420924097 / Flux corr for the order
# HIERARCH ESO QC ORDER169 FLUX CORR = 1.35575940103354 / Flux corr for the order
# HIERARCH ESO QC ORDER170 FLUX CORR = 1.35576020066765 / Flux corr for the order
# HIERARCH ESO QC FLUX CORR MIN = 0.588323991939326 / Min of flux correction
# HIERARCH ESO QC FLUX CORR MAX = 1.35576020066765 / Max of flux correction
# HIERARCH ESO QC SCIRED FLUX CORR CHECK = 1 / Flux correction QC
# HIERARCH ESO QC CCF RV = -2.13376575829583 / Radial velocity [km/s]
# HIERARCH ESO QC CCF RV ERROR = 0.000283030822932362 / Uncertainty on radial velo
# HIERARCH ESO QC CCF FWHM = 8.34579058732021 / CCF FWHM [km/s]
# HIERARCH ESO QC CCF FWHM ERROR = 0.000566061645864725 / Uncertainty on CCF FWHM
# HIERARCH ESO QC CCF CONTRAST = 61.625824247107 / CCF contrast %
# HIERARCH ESO QC CCF CONTRAST ERROR = 0.00417983355035137 / CCF contrast error %
# HIERARCH ESO QC CCF CONTINUUM = 9930574.89282971 / CCF continuum level [e-]
# HIERARCH ESO QC CCF MASK = 'K2      ' / CCF mask used
# HIERARCH ESO QC CCF FLUX ASYMMETRY = 0.0250189232146722 / CCF asymmetry (km/s)
# HIERARCH ESO QC CCF FLUX ASYMMETRY ERROR = 0.000500187516325561 / CCF asymmetry
# HIERARCH ESO QC CCF BIS SPAN = -0.0230307789478421 / CCF bisector span (km/s)
# HIERARCH ESO QC CCF BIS SPAN ERROR = 0.000566061645864725 / CCF bisector span er
# HIERARCH ESO QC SCIRED CHECK = 1 / SCIRED global QC
# CHECKSUM= '7pfKAndJ8ndJAndJ'   / HDU checksum updated 2021-08-12T00:29:20
# DATASUM = '         0'         / data unit checksum updated 2021-08-12T00:29:20

# %%
#opening and storing white light CCFs day 11
CCFs = np.zeros((len(list_ccfs),2, f.shape[1]))
CCF_rv = np.zeros((len(list_ccfs),f.shape[1]))
Time = []
Air = []

RV_reference = 0

for i,name in enumerate(list_ccfs):

    d = fits.getdata(name,1)
    de = fits.getdata(name,2)
    h = fits.getheader(name)

    N = len(d[-1])
    a = h['HIERARCH ESO RV START']
    step = h['HIERARCH ESO RV STEP']
    t = h['HIERARCH ESO QC BJD']
    air = h['HIERARCH ESO TEL1 AIRM START']
    Time.append(t)
    Air.append(air)
    X = np.arange(a,a+step*N,step)

    CCFs[i,0,:] = d[-1]
    CCFs[i,1,:] = de[-1]
    CCF_rv[i] = X

    if i == 0:
        RV_reference = X + 2
    
Time = np.array(Time)
Air = np.array(Air)

# %% [markdown]
# ## Fitting modified gaussian

# %%
from scipy.optimize import curve_fit

def modified_gaussfit(x,y0,a,x0,sigma,c):
    return y0-a*np.exp(-0.5*((np.abs(x-x0)/sigma)**c))

# %%
y0 = np.zeros((len(list_ccfs),2))
x0 = np.zeros((len(list_ccfs),2))

for i in range(len(list_ccfs)):
    d = CCFs[i,0]
    de = CCFs[i,1]
    rv = CCF_rv[i]


    p0 =          [np.max(d), np.max(d)-np.min(d),           0,       1,       1] #y0, a, x0, sigma, c
    upper_bound = [   np.inf,              np.inf,  np.max(rv),  np.inf,  np.inf]
    lower_bound = [        0,                   0,  np.min(rv),       0,       0]


    popt, pcov = curve_fit(f=modified_gaussfit, xdata=rv, ydata=d, sigma=de, 
                           bounds=(lower_bound,upper_bound), absolute_sigma=True, p0=p0)

    x0[i,0], x0[i,1] = popt[2], np.sqrt(pcov[2,2])
    y0[i,0], y0[i,1] = popt[0], np.sqrt(pcov[0,0])


plt.figure(figsize=(8,4))
plt.errorbar(x=Time-2450000,y=x0[:,0],yerr = x0[:,1], capsize=3, capthick=0.5, fmt="k.")
plt.ylabel('Radial Velocities [km/]')
plt.xlabel('Time - 2450000 [d]')
plt.title('Central values of CCFs')
plt.grid()
plt.show()

# %%
def phase(date,tepoch, P_orb):
    norb = (date-tepoch)/P_orb
    nforb = [round(x) for x in norb]
    return norb-nforb

# %%
#cristo et al.
#table 4
Vsys = -2.18095 #km/s
Prot = 11.454 #dias
istar = 71.87 #º
alphaB = 0.29
VCB = -211 #m/s
ip = 85.465 #º
lamda = -1.00 #º
aR = 8.7686 #in star radiuses
RpRs = 0.1602
mp =  356.9 #m⊕
dfp = -0.002424
alphaw = -50.4 #cm/s
#table E.1
Rstar = 0.766 #R⊙
Teff = 4969 #K
e_Teff = 43
P_orb = 2.21857312 #dias
T0 = 53988.30339

logg = 4.60 
e_logg = 0.01
feh = -0.07
e_feh = 0.02

# %%
tepoch = T0 + 0.5+2.4e6 -dfp*P_orb#MBJD

phases = phase(Time, tepoch, P_orb)
print(phases) #em Porbit
# Out:
# [-0.03878006 -0.03700934 -0.03514845 -0.03318259 -0.03133248 -0.02944812
#  -0.02757787 -0.02564173 -0.0237944  -0.02191848 -0.02002154 -0.01812612
#  -0.01628159 -0.01441559 -0.0124982  -0.0106569  -0.008787   -0.00682509
#  -0.00500114 -0.00311627 -0.00126897  0.0006282   0.00254259  0.00440799
#   0.00626933  0.00817742  0.01004104  0.01192976  0.01379679  0.0156898
#   0.01753608  0.01941469  0.02131465  0.02321891  0.02502994  0.02699783
#   0.02883662  0.03071907  0.03260208  0.03416093]

# %%
tr_dur=1./np.pi * np.arcsin(1./aR *np.sqrt((1+RpRs)**2.-aR**2. *np.cos(np.radians(ip))**2.))

tr_ingress_egress=1./np.pi * np.arcsin(1./aR *np.sqrt((1.-RpRs)**2.-aR**2. *np.cos(np.radians(ip))**2.))

# %%
plt.figure(figsize=(15,6))
plt.axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange',label='ingress+egress')
plt.axvspan(tr_ingress_egress/2.-tr_dur/2, -tr_ingress_egress/2.+tr_dur/2, alpha=0.4, color='orange',label='middle of transit')
plt.scatter(phases, Air,color='black')
plt.xlabel('Orbital phase')
plt.grid()
plt.ylabel('Airmass')
plt.legend()
plt.title('Airmass at start of observation in function of orbital phases')
# Out:
# Text(0.5, 1.0, 'Airmass at start of observation in function of orbital phases')

# %% [markdown]
# ## RV correction and normalization

# %%
out_indices = np.where(np.abs(phases) >  tr_dur/2)[0]
in_indices  = np.where(np.abs(phases) <= tr_dur/2)[0]

poly_coefs, poly_cov = np.polyfit(phases[out_indices], x0[:,0][out_indices], w=1/x0[:,1][out_indices],deg=1,cov=True)

x0_corr = np.zeros_like(x0)
CCFs_corr = np.zeros_like(CCFs)
CCF_rv_corr = np.zeros_like(CCF_rv)

for i in range(len(list_ccfs)):
    d = CCFs[i,0]
    de = CCFs[i,1]
    
    d_corr = d/y0[i,0]
    
    x0_corr[i,0] = x0[i,0] - (poly_coefs[0]*phases[i] + poly_coefs[1])
    CCF_rv_corr[i] = CCF_rv[i] - (poly_coefs[0]*phases[i] + poly_coefs[1])
    CCFs_corr[i,0] = d_corr

    CCFs_corr[i,1] = d_corr * np.sqrt( (y0[i,1]/y0[i,0])**2 + (de/d)**2 )
    x0_corr[i,1] = np.sqrt( x0[i,1]**2 + poly_cov[0,0]*phases[i]**2 + poly_cov[1,1])

# %%
fig, axes = plt.subplots(ncols=2, figsize=(13,4))

l0 = axes[0].axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange')
l1 = axes[0].axvspan(tr_ingress_egress/2.-tr_dur/2, -tr_ingress_egress/2.+tr_dur/2, alpha=0.4, color='orange')
l2 = axes[0].errorbar(phases[in_indices], x0[:,0][in_indices], x0[:,1][in_indices], fmt="r.", markersize=10, elinewidth=10)
l3 = axes[0].errorbar(phases[out_indices], x0[:,0][out_indices], x0[:,1][out_indices], fmt="k.", markersize=10, elinewidth=10)
l4 = axes[0].plot(phases[out_indices], poly_coefs[:,0]*phases[out_indices]+poly_coefs[1], color="black", lw=1)

axes[0].set_ylabel('Radial Velocities (km/s)')
axes[0].set_xlabel('Orbital Phases')
axes[0].grid()
axes[0].set_axisbelow(True)


axes[1].axvspan(-tr_dur/2, tr_dur/2, alpha=0.3, color="orange")
axes[1].axvspan(tr_ingress_egress/2.-tr_dur/2, -tr_ingress_egress/2.+tr_dur/2, alpha=0.4, color='orange')
axes[1].errorbar(phases[in_indices], x0_corr[:,0][in_indices], x0_corr[:,1][in_indices], fmt="r.", markersize=10, elinewidth=10)
axes[1].errorbar(phases[out_indices], x0_corr[:,0][out_indices], x0_corr[:,1][out_indices], fmt="k.", markersize=10, elinewidth=10)
axes[1].axhline(0, lw=1, ls= "--", color="k")
axes[1].set_ylabel('Radial Velocities (km/s)')
axes[1].set_xlabel('Orbital Phases')
axes[1].grid()
axes[1].set_axisbelow(True)

labels = ['ingress+egress','middle of transit','in transit','out of transit','out of transit linear fit']
fig.legend([l0,l1,l2,l3,l4], labels=labels, loc='lower center',ncol=5, bbox_to_anchor=(0.5, -0.12))
fig.suptitle('Central values of CCFs',fontsize=19)
plt.show()

# %%
M = CCFs_corr.shape[0]
K = CCFs_corr.shape[2]
cov_matrix = np.zeros((M, K, K))
N = 10000

for i in range(M):
    samples = np.zeros((K, N))
    for j in range(K):
        ymean = CCFs_corr[i,0,j]
        ysigma = CCFs_corr[i,1,j]
        samples[j,:] = np.random.normal(ymean, ysigma, N)
    cov_ccf = np.cov(samples)
    cov_matrix[i,:,:] = cov_ccf

# %%
def linear_interpolation_matrix(x_old, x_new):
    """
    Builds a sparse matrix W that linearly interpolates data from x_old → x_new.
    Each row i corresponds to interpolation weights for x_new[i].
    """
    W = lil_matrix((len(x_new), len(x_old)))

    for i, xv in enumerate(x_new):
        if xv <= x_old[0]:
            # extrapolate using first two points
            j = 0
            x0, x1 = x_old[j], x_old[j+1]
            w1 = (x1 - xv) / (x1 - x0)
            w2 = (xv - x0) / (x1 - x0)
        elif xv >= x_old[-1]:
            # extrapolate using last two points
            j = len(x_old) - 2
            x0, x1 = x_old[j], x_old[j+1]
            w1 = (x1 - xv) / (x1 - x0)
            w2 = (xv - x0) / (x1 - x0)
        else:
            j = np.searchsorted(x_old, xv) - 1
            x0, x1 = x_old[j], x_old[j+1]
            w1 = (x1 - xv) / (x1 - x0)
            w2 = (xv - x0) / (x1 - x0)

        W[i, j]   = w1
        W[i, j+1] = w2

    return W.tocsr()


# Preallocate results
out_of_transit_CCFs = np.zeros([len(out_indices), len(RV_reference), 2])
in_transit_CCF = np.zeros([CCFs.shape[0] - len(out_indices), len(RV_reference)])

interp_CCF_flux = np.zeros([CCFs.shape[0], CCFs.shape[2], 2])

k, M = 0, 0
RV_target = RV_reference  # your adjusted target grid

for l in range(CCFs.shape[0]):
    ccf_f = CCFs_corr[l,0]
    ccf_f_e = cov_matrix[l]       # full covariance matrix
    ccf_rv = CCF_rv_corr[l]

    # Build interpolation matrix for this CCF → target grid
    W = linear_interpolation_matrix(ccf_rv, RV_target)

    # Interpolated flux
    y_i = W @ ccf_f

    # Propagated covariance and uncertainty
    cov_new = W @ ccf_f_e @ W.T
    y_i_e = np.sqrt(cov_new.diagonal())

    interp_CCF_flux[l,:,0] = y_i
    interp_CCF_flux[l,:,1] = y_i_e

    # Separate out-of-transit vs in-transit
    if l in out_indices:
        out_of_transit_CCFs[k,:,0] = y_i
        out_of_transit_CCFs[k,:,1] = y_i_e
        k += 1
    else:
        in_transit_CCF[M] = y_i
        M += 1

# Compute master out-of-transit CCF and its uncertainty
average_out_of_transit_CCF = np.mean(out_of_transit_CCFs[:,:,0], axis=0)
A_e = np.sum(out_of_transit_CCFs[:,:,1]**2, axis=0)
average_out_of_transit_CCF_e = np.sqrt(A_e) / len(out_indices)


avg_out_of_transit_CCF = np.array([average_out_of_transit_CCF, average_out_of_transit_CCF_e])
avg_out_of_transit_CCF
# Out:
# array([[1.01560968e+00, 1.01355346e+00, 1.01152145e+00, 1.00960120e+00,
#         1.00774582e+00, 1.00595622e+00, 1.00424555e+00, 1.00253844e+00,
#         1.00087066e+00, 9.99178139e-01, 9.97337099e-01, 9.95325917e-01,
#         9.93080330e-01, 9.90615586e-01, 9.87921085e-01, 9.85048826e-01,
#         9.81976925e-01, 9.78661862e-01, 9.75091405e-01, 9.71148106e-01,
#         9.66704766e-01, 9.61443880e-01, 9.54920964e-01, 9.46539081e-01,
#         9.35663622e-01, 9.21568951e-01, 9.03366841e-01, 8.80240054e-01,
#         8.51547429e-01, 8.16927165e-01, 7.76420237e-01, 7.30505691e-01,
#         6.80301068e-01, 6.27361827e-01, 5.73761433e-01, 5.21888899e-01,
#         4.74436522e-01, 4.34007278e-01, 4.02959534e-01, 3.83299437e-01,
#         3.76384966e-01, 3.82703147e-01, 4.01915860e-01, 4.32705131e-01,
#         4.73165584e-01, 5.20890748e-01, 5.73144051e-01, 6.27207926e-01,
#         6.80578730e-01, 7.31050084e-01, 7.77071656e-01, 8.17712771e-01,
#         8.52480767e-01, 8.81411573e-01, 9.04984643e-01, 9.23855930e-01,
#         9.38725939e-01, 9.50421051e-01, 9.59676855e-01, 9.67047823e-01,
#         9.73041522e-01, 9.78022649e-01, 9.82236955e-01, 9.85999658e-01,
#         9.89372842e-01, 9.92296772e-01, 9.94817833e-01, 9.97109634e-01,
#         9.99238948e-01, 1.00111889e+00, 1.00287890e+00, 1.00456145e+00,
#         1.00611502e+00, 1.00767507e+00, 1.00920119e+00, 1.01076358e+00,
#         1.01234163e+00, 1.01382601e+00, 1.01519257e+00, 1.01641826e+00,
#         1.01751791e+00],
#        [5.59739920e-05, 2.98816245e-05, 2.98682884e-05, 2.98763535e-05,
#         2.96988625e-05, 2.97364800e-05, 2.97446447e-05, 2.96317797e-05,
#         2.95874810e-05, 2.95957362e-05, 2.94769172e-05, 2.94927751e-05,
#         2.94496509e-05, 2.93364504e-05, 2.92790053e-05, 2.91917767e-05,
#         2.91268346e-05, 2.90474192e-05, 2.89629887e-05, 2.88122990e-05,
#         2.86219274e-05, 2.85623309e-05, 2.83089366e-05, 2.82227437e-05,
#         2.80015615e-05, 2.76510224e-05, 2.71612337e-05, 2.67064056e-05,
#         2.61091615e-05, 2.53715461e-05, 2.45669842e-05, 2.35875309e-05,
#         2.25640748e-05, 2.14664871e-05, 2.03465678e-05, 1.92098454e-05,
#         1.81580281e-05, 1.72352360e-05, 1.64921729e-05, 1.60514961e-05,
#         1.59146909e-05, 1.61487356e-05, 1.66635516e-05, 1.74258714e-05,
#         1.83828637e-05, 1.95011570e-05, 2.06934401e-05, 2.18077541e-05,
#         2.28823283e-05, 2.39152876e-05, 2.48963761e-05, 2.57013120e-05,
#         2.63330658e-05, 2.69258074e-05, 2.75039136e-05, 2.78765999e-05,
#         2.81622239e-05, 2.84311764e-05, 2.85548985e-05, 2.88129649e-05,
#         2.89056186e-05, 2.89936711e-05, 2.91689428e-05, 2.92555509e-05,
#         2.92758760e-05, 2.93916581e-05, 2.94025371e-05, 2.95223900e-05,
#         2.95926441e-05, 2.96216072e-05, 2.96218825e-05, 2.97736400e-05,
#         2.97003000e-05, 2.97240402e-05, 2.98654550e-05, 2.98710985e-05,
#         2.99043556e-05, 2.99209905e-05, 2.99085190e-05, 3.00691729e-05,
#         3.00659929e-05]])

# %%
plt.figure(figsize=(7,4))
plt.scatter(RV_reference, avg_out_of_transit_CCF[0])
plt.errorbar(x=RV_reference, y=avg_out_of_transit_CCF[0],yerr =avg_out_of_transit_CCF[1],capsize=7,capthick=1,color='black',linewidth=0,elinewidth=1)
plt.title('Averaged out of transit CCF')
plt.xlabel('Radial Velocities (km/s)')
plt.ylabel('Normalized flux')
plt.show()

# %% [markdown]
# ## Photometric light curve

# %%
#coeficientes de limb darkening
filters = [BoxcarFilter('filter', 380, 788)] #expresso spectograph bandpass 380, 788nm
sc = LDPSetCreator(teff=(Teff, e_Teff),  
logg=(logg, e_logg),
z=(feh, e_feh),
filters=filters)
ps = sc.create_profiles()      	         #create the limb darkening profiles
ldcn, qe = ps.coeffs_qd(do_mc=True) #coeficientes e os seus erros de perfil quadrático
ldcn
# Out:
# array([[0.6461717, 0.0845909]])

# %%
#curva de luz
sim = SOAP.Simulation()
sim.star.set(prot = Prot,incl =istar,radius=Rstar,teff=Teff,u1=ldcn[0,0], u2=ldcn[0,1])
sim.planet.set(P=P_orb, t0=0, e=0.0, w=90.0,ip=ip,lbda=lamda,a=aR,Rp=RpRs)

output = sim.calculate_signal(psi=phases/Prot*P_orb,skip_rv=True)
Flux_SOAP = output.flux

fig = plt.figure(figsize=(8,5))

plt.axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange', label="middle of transit")
plt.axvspan(-tr_ingress_egress/2., tr_ingress_egress/2., alpha=0.4, color='orange', label="ingress+egress")
plt.scatter(phases, Flux_SOAP, color="k")
plt.title('SOAP transit light curve')
plt.ylabel("Normalized Flux")
plt.xlabel("Orbital Phases")
plt.legend(fontsize=14)

plt.show()

# %% [markdown]
# ## Local white light CCFs

# %%
CCFs_flux_corr = np.zeros_like(CCFs_corr) #only flux corrected
CCFs_sub_all = np.zeros_like(CCFs_corr) #flux corrected and subtracted
local_CCFs = np.zeros((len(in_indices), 2, CCFs_corr.shape[2])) #above but only in transit

l = 0
for i in range(CCFs_flux_corr.shape[0]):

    d = interp_CCF_flux[i,:,0]
    de = interp_CCF_flux[i,:,1]
    
    #performing the Doppler shadow technique
    sub = avg_out_of_transit_CCF[0] - d*Flux_SOAP[i]

    d_corr = d*Flux_SOAP[i]
    de_corr = np.sqrt(avg_out_of_transit_CCF[1]**2+(de*Flux_SOAP[i])**2)

    CCFs_sub_all[i,0] = sub
    CCFs_sub_all[i,1] = de_corr

    if i in in_indices:
        
        CCFs_flux_corr[i,0] = d_corr
        CCFs_flux_corr[i,1] = de*Flux_SOAP[i]

        local_CCFs[l,0] = sub
        local_CCFs[l,1] = de_corr

        l += 1

# %%
fig, axes = plt.subplots(figsize=(15,7.5))

norm = Normalize(vmin=phases[in_indices].min(), vmax=phases[in_indices].max())
cmap = plt.get_cmap('coolwarm_r')

for k, idx in enumerate(in_indices):

    sub     = local_CCFs[k,0]
    de_corr = local_CCFs[k,1]

    color = cmap(norm(phases[idx]))

    axes.scatter(RV_target, sub, color=color, s=50, label=str(phases[idx])[:6])
    axes.errorbar(RV_target, sub, yerr=de_corr,
                    color='black', capsize=5, linewidth=0, elinewidth=1)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  
cbar = fig.colorbar(sm, ax=axes)
cbar.set_label('Orbital phase')

axes.set_title('Local white light CCFs')
axes.set_ylabel('Relative flux [total stellar flux]')
axes.set_xlabel('Radial Velocities [km/s]')
axes.grid()
plt.show()

# %% [markdown]
# ## Fits

# %%
def r2(y,yfit):
    ssres = np.sum((y-yfit)**2)
    sstot = np.sum((y-np.mean(y))**2)
    r = 1- ssres/sstot
    return r

# %%
#impact parameter
b = aR*np.cos(ip*np.pi/180)

# calculating minimum and maximum mu for the shaded regions in the plots
def mu(phases):
    return np.sqrt(1 - b**2 - (aR*np.sin(2*np.pi*np.abs(phases)))**2 )
mu_min = mu(tr_dur/2-tr_ingress_egress/2)
mu_max = mu(0)

# %%
#MASTER OUT OF TRANSIT parameter fitting for comparison
p0 =          [np.max(avg_out_of_transit_CCF[0]), np.max(avg_out_of_transit_CCF[0])-np.min(avg_out_of_transit_CCF[0]),           0,       1,       1] #y0, a, x0, sigma, c
upper_bound = [   np.inf,              np.inf,  np.max(rv),  np.inf,  np.inf]
lower_bound = [        0,                   0,  np.min(rv),       0,       0]


popt, pcov = curve_fit(f=modified_gaussfit, xdata=RV_target, ydata=avg_out_of_transit_CCF[0], sigma=avg_out_of_transit_CCF[1], bounds = (lower_bound,upper_bound), absolute_sigma=True, p0=p0)
gd = modified_gaussfit(RV_target,popt[0],popt[1],popt[2],popt[3],popt[4])

print('y_0 = '+str(popt[0])[:6]+'±'+str(np.sqrt(pcov[0,0]))[:6]+', a = '+str(popt[1])[:6]+'±'+str(np.sqrt(pcov[1,1]))[:6]+', x_0 = '+str(popt[2])[:6]+'±'+str(np.sqrt(pcov[2,2]))[:6]+', sigma = '+str(popt[3])[:6]+'±'+str(np.sqrt(pcov[3,3]))[:6]+', c = '+str(popt[4])[:6]+'±'+str(np.sqrt(pcov[4,4]))[:6])

master_x0 = popt[2]
master_x0_err = np.sqrt(pcov[2,2])

master_depth = (1-(popt[1]/popt[0]))*100
master_depth_err = ((popt[1]/popt[0])*np.sqrt(np.abs(pcov[1,1])/(popt[1]**2)+np.abs(pcov[0,0])/(popt[0]**2)))*100

master_width = popt[3] 
master_width_err = np.sqrt(pcov[3,3])

master_y0 = popt[0]
master_y0_err = np.sqrt(pcov[0,0])


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,7), gridspec_kw={'height_ratios': [1.7, 1]})
fig.suptitle('Master out of transit white light CCF')

axes[0,0].scatter(RV_target, avg_out_of_transit_CCF[0], color="k")
axes[0,0].errorbar(RV_target, avg_out_of_transit_CCF[0], yerr=avg_out_of_transit_CCF[1],
                    color='black', capsize=5, linewidth=0, elinewidth=1)
axes[0,0].plot(RV_target,gd,label='fit', color="r", lw=2)
axes[0,0].set_xlabel('Radial Velocities [km/s]')
axes[0,0].set_ylabel('CCF')
axes[0,0].grid()
axes[0,0].set_axisbelow(True)
axes[0,0].legend()


axes[0,1].scatter(RV_target, avg_out_of_transit_CCF[0]-gd, color="k")
axes[0,1].set_xlabel('Radial Velocities [km/s]')
axes[0,1].set_ylabel('Residuals')
axes[0,1].grid()
axes[0,1].set_axisbelow(True)


axes[1,0].hist(avg_out_of_transit_CCF[0]-gd, bins=10, edgecolor='k', color="k")
axes[1,0].set_xlabel('Residuals')
axes[1,0].set_ylabel('Frequency')
axes[1,0].grid()
axes[1,0].set_axisbelow(True)

axes[1,1].hist(de, bins=10, edgecolor='k', color="k")
axes[1,1].set_xlabel('Uncertainties')
axes[1,1].set_ylabel('Frequency')
axes[1,1].grid()
axes[1,1].set_axisbelow(True)
axes[1,1].tick_params(axis='x', which='major', labelsize=12)

plt.tight_layout()
plt.show()

print("R^2: ", r2(avg_out_of_transit_CCF[0],gd))
# Out:
# y_0 = 0.9997±4.9372, a = 0.6295±1.0524, x_0 = -0.000±4.9174, sigma = 3.4045±9.0082, c = 1.8237±8.4584
# R^2:  0.998347960392883

# %%
#in transit local CCFs parameter fitting
in_phases = phases[np.isin(np.arange(len(phases)), in_indices)]
mu_in = mu(in_phases)

y0_local = np.zeros((local_CCFs.shape[0],2))
x0_local = np.zeros((local_CCFs.shape[0],2))
width_local = np.zeros((local_CCFs.shape[0],2))
depth_local = np.zeros((local_CCFs.shape[0],2))

RR2 = []

for i in range(local_CCFs.shape[0]):

    d = local_CCFs[i,0]
    de = local_CCFs[i,1]

    p0 =          [np.max(d), np.max(d)-np.min(d),           0,       1,       1] #y0, a, x0, sigma, c
    upper_bound = [   np.inf,              np.inf,  np.max(rv),  np.inf,  np.inf]
    lower_bound = [        0,                   0,  np.min(rv),       0,       0]

    popt, pcov = curve_fit(f=modified_gaussfit, xdata=RV_target, ydata=d, sigma=de, 
                           bounds=(lower_bound,upper_bound), absolute_sigma=True, p0=p0)
    gd = modified_gaussfit(RV_target, popt[0], popt[1], popt[2], popt[3], popt[4])

    print('y_0 = '+str(popt[0])[:6]+'±'+str(np.sqrt(pcov[0,0]))[:6]+', a = '+str(popt[1])[:6]+'±'+str(np.sqrt(pcov[1,1]))[:6]+', x_0 = '+str(popt[2])[:6]+'±'+str(np.sqrt(pcov[2,2]))[:6]+', sigma = '+str(popt[3])[:6]+'±'+str(np.sqrt(pcov[3,3]))[:6]+', c = '+str(popt[4])[:6]+'±'+str(np.sqrt(pcov[4,4]))[:6])

    y0_local[i,0], y0_local[i,1] = popt[0], np.sqrt(pcov[0,0])
    x0_local[i,0], x0_local[i,1] = popt[2], np.sqrt(pcov[2,2])
    width_local[i,0], width_local[i,1] = popt[3], np.sqrt(pcov[3,3])
    depth_local[i,0], depth_local[i,1] = (1-popt[1]/popt[0])*100, ((popt[1]/popt[0])*np.sqrt(np.abs(pcov[1,1])/(popt[1]**2)+np.abs(pcov[0,0])/(popt[0]**2)))*100

    RR2.append(r2(d,gd))

        
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,7), gridspec_kw={'height_ratios': [1.7, 1]})
    fig.suptitle(rf'Local white light CCF at $\phi = $ {str(in_phases[i])[:6]}')

    axes[0,0].scatter(RV_target, d, color="k")
    axes[0,0].errorbar(RV_target, d, yerr=de,
                    color='black', capsize=5, linewidth=0, elinewidth=1)
    axes[0,0].plot(RV_target, gd, label='fit', color="r", lw=2)
    axes[0,0].set_xlabel('Radial Velocities [km/s]')
    axes[0,0].set_ylabel('CCF')
    axes[0,0].grid()
    axes[0,0].set_axisbelow(True)
    axes[0,0].legend()

    axes[0,1].scatter(RV_target, d-gd, color="k")
    axes[0,1].set_xlabel('Radial Velocities [km/s]')
    axes[0,1].set_ylabel('Residuals')
    axes[0,1].grid()
    axes[0,1].set_axisbelow(True)

    axes[1,0].hist(d-gd, bins=10, edgecolor='k', color="k")
    axes[1,0].set_xlabel('Residuals')
    axes[1,0].set_ylabel('Frequency')
    axes[1,0].grid()
    axes[1,0].set_axisbelow(True)

    axes[1,1].hist(de, bins=10, edgecolor='k', color="k")
    axes[1,1].set_xlabel('Uncertainties')
    axes[1,1].set_ylabel('Frequency')
    axes[1,1].grid()
    axes[1,1].set_axisbelow(True)
    axes[1,1].tick_params(axis='x', which='major', labelsize=12)

    plt.tight_layout()
    plt.show()
# Out:
# y_0 = 0.0005±1.9171, a = 0.0003±7.7589, x_0 = -3.256±0.2990, sigma = 1.8511±0.6579, c = 1.5000±0.6505
# y_0 = 0.0045±2.2596, a = 0.0029±5.9840, x_0 = -2.362±0.0491, sigma = 2.9066±0.0939, c = 1.7897±0.0943
# y_0 = 0.0106±2.1897, a = 0.0069±5.3852, x_0 = -2.107±0.0204, sigma = 3.1354±0.0371, c = 1.9230±0.0406
# y_0 = 0.0167±2.2600, a = 0.0108±5.3577, x_0 = -1.818±0.0134, sigma = 3.2039±0.0239, c = 1.9779±0.0275
# y_0 = 0.0216±2.3089, a = 0.0143±5.4408, x_0 = -1.470±0.0102, sigma = 3.1497±0.0184, c = 1.9286±0.0204
# y_0 = 0.0240±1.9696, a = 0.0165±4.6306, x_0 = -1.143±0.0074, sigma = 3.0700±0.0134, c = 1.8892±0.0148
# y_0 = 0.0253±1.8832, a = 0.0178±4.3908, x_0 = -0.881±0.0065, sigma = 3.0306±0.0117, c = 1.9063±0.0133
# y_0 = 0.0260±1.8222, a = 0.0184±4.2182, x_0 = -0.546±0.0060, sigma = 3.0024±0.0109, c = 1.8773±0.0122
# y_0 = 0.0266±1.8091, a = 0.0189±4.1930, x_0 = -0.244±0.0058, sigma = 3.0363±0.0105, c = 1.9293±0.0124
# y_0 = 0.0267±1.8918, a = 0.0190±4.3772, x_0 = 0.0597±0.0061, sigma = 3.0193±0.0110, c = 1.8870±0.0124
# y_0 = 0.0264±1.8586, a = 0.0187±4.2920, x_0 = 0.3760±0.0061, sigma = 3.0376±0.0110, c = 1.9100±0.0126
# y_0 = 0.0255±1.7860, a = 0.0183±4.2481, x_0 = 0.7330±0.0060, sigma = 2.9844±0.0110, c = 1.8724±0.0122
# y_0 = 0.0245±1.8385, a = 0.0172±4.3629, x_0 = 1.0342±0.0066, sigma = 3.0186±0.0120, c = 1.8799±0.0133
# y_0 = 0.0225±1.8533, a = 0.0156±4.4885, x_0 = 1.3410±0.0074, sigma = 3.0271±0.0135, c = 1.8948±0.0150
# y_0 = 0.0186±1.8226, a = 0.0127±4.4716, x_0 = 1.6459±0.0090, sigma = 3.0403±0.0165, c = 1.8890±0.0181
# y_0 = 0.0125±1.8167, a = 0.0083±4.4652, x_0 = 1.9100±0.0139, sigma = 3.0999±0.0251, c = 1.9511±0.0287
# y_0 = 0.0063±1.6958, a = 0.0042±4.1603, x_0 = 2.1002±0.0257, sigma = 3.1244±0.0437, c = 2.2000±0.0633
# y_0 = 0.0015±1.5594, a = 0.0011±3.8618, x_0 = 1.8989±0.0840, sigma = 2.9330±0.1350, c = 2.5411±0.2799

# %%
#tomography
X,Y = np.meshgrid(RV_target, phases)

fig,ax = plt.subplots(figsize=(14,6))

im = ax.imshow(CCFs_sub_all[:,0], cmap='jet', extent=[RV_target.min(), RV_target.max(), phases.min(), phases.max()], 
               aspect='auto', origin='lower')

l1=ax.scatter(x0_local[:,0], in_phases, marker='x', color='red', label='Central RV', s=50)
l2= ax.errorbar(x=x0_local[:,0], y=in_phases, xerr=x0_local[:,1], 
                color='black',capsize=5,capthick=0.5,linewidth=0,elinewidth=2)
l3=ax.axhline(y=-tr_dur/2, color='black')
ax.axhline(y=tr_dur/2, color='black')
l4=ax.axhline(y=-tr_ingress_egress/2, color='black',linestyle='--')
ax.axhline(y=tr_ingress_egress/2, color='black',linestyle='--')

ax.set_xlabel('Radial Velocities [km/s]')
ax.set_ylabel('Orbital Phase')
ax.set_title('Tomography of local white light CCFs')

cbar = plt.colorbar(im)
cbar.set_label('Relative flux [total stellar flux]',labelpad=15)

labels = ['Central values','in transit limit','ingress/egress limit']
fig.legend([l1,l3,l4], labels=labels, loc='lower center',ncol=5, bbox_to_anchor=(0.45, -0.1))
plt.rcParams.update({'font.size': 17})

# %% [markdown]
# ## Parameters

# %%
fig, ax = plt.subplots(figsize=(6,4))

l1=ax.scatter(in_phases, RR2, color="k")
ax.axhline(y=0.5,color='black',linestyle='-')

ax.set_title('R² of fits of the local white light CCFs',fontsize=14)
ax.set_xlabel('Orbital Phase',fontsize=15)
ax.set_ylabel('R²',fontsize=15)
ax.grid()
ax.set_axisbelow(True)

plt.show()

# %%
#statistical quantities
def chisquare(x,y,m,b,s):
    r = np.sum(((y-(x*m+b))/s)**2)
    rr = np.sum(((y-np.mean(y))/s)**2)
    return [r,rr]

def p_coef(x,y):
    xm = np.mean(x)
    ym = np.mean(y)
    a =np.sum((x-xm)*(y-ym))
    aa = np.sum((x-xm)**2)
    aaa = np.sum((y-ym)**2)
    p = a/np.sqrt(aa*aaa)
    return p

def spearman(x,y,y_err):
    n = 10000 
    rho_sim = np.zeros(n)
    p_sim = np.zeros(n) 

    for i in range(n):
        #Generate random weights using mean weights with measurement error
        y_sim = np.random.normal(y,y_err,len(y))
        #Calculate correlation coefficient and p-value
        rho_sim[i],p_sim[i] = spearmanr(x,y_sim)
    return rho_sim,p_sim

# %%
#discard points based on R² plot
inner = np.arange(2,len(mu_in)-2)

coefs_poly_rv, cov_poly_rv = np.polyfit(in_phases[inner], x0_local[:,0][inner], w=1/x0_local[:,1][inner], deg=1, cov=True)
chi_x0 = chisquare(in_phases[inner], x0_local[:,0][inner], coefs_poly_rv[0], coefs_poly_rv[1], x0_local[:,0][inner])
pearson_x0 = p_coef(in_phases[inner], x0_local[:,0][inner])
r2_x0 = r2(x0_local[:,0][inner], coefs_poly_rv[0]*in_phases[inner]+coefs_poly_rv[1])
spear_x0, spear_pval_x0 = spearman(in_phases[inner], x0_local[:,0][inner], x0_local[:,1][inner])
spearr_x0, spearr_pval_x0 = spearmanr(in_phases[inner], x0_local[:,0][inner])

print('Central RV in function of orbital phases')
print('\n fit values, m = '+str(coefs_poly_rv[0])[:6]+'±'+str(np.sqrt(cov_poly_rv[0,0]))[:6]+', b = '+str(coefs_poly_rv[1])[:6]+'±'+str(np.sqrt(cov_poly_rv[1,1]))[:6])
print('Χ² = '+str(chi_x0))
print('pearson = '+str(pearson_x0))
print('r² = '+str(r2_x0))
print('spearman = '+str(spearr_x0))
print('p-value = '+str(np.log10(spearr_pval_x0)))
print('\n')

#-------------------

coefs_poly_width, cov_poly_width = np.polyfit(mu_in[inner], width_local[:,0][inner], w=1/width_local[:,1][inner], deg=1, cov=True)
chi_width = chisquare(mu_in[inner], width_local[:,0][inner], coefs_poly_width[0], coefs_poly_width[1], width_local[:,1][inner])
pearson_width = p_coef(mu_in[inner], width_local[:,0][inner])
r2_width = r2(width_local[:,0][inner], coefs_poly_width[0]*mu_in[inner]+coefs_poly_width[1])
spear_width, spear_pval_width = spearman(mu_in[inner], width_local[:,0][inner], width_local[:,1][inner])
spearr_width, spearr_pval_width = spearmanr(mu_in[inner], width_local[:,0][inner])

print('Line-width measure in function of mu')
print('\nfit values, m = '+str(coefs_poly_width[0])[:5]+'±'+str(np.sqrt(cov_poly_width[0,0]))[:5]+', b = '+str(coefs_poly_width[1])[:5]+'±'+str(np.sqrt(cov_poly_width[1,1]))[:5])
print('Χ² = '+str(chi_width))
print('pearson = '+str(pearson_width))
print('r² = '+str(r2_width))
print('spearman = '+str(spearr_width))
print('p-value = '+str(np.log10(spearr_pval_width)))
print('\n')

#-------------------

coefs_poly_depth, cov_poly_width = np.polyfit(mu_in[inner], depth_local[:,0][inner], w=1/depth_local[:,1][inner], deg=1, cov=True)
chi_depth = chisquare(mu_in[inner], depth_local[:,0][inner], coefs_poly_depth[0], coefs_poly_depth[1], depth_local[:,1][inner])
pearson_depth = p_coef(mu_in[inner], depth_local[:,0][inner])
r2_depth = r2(depth_local[:,0][inner], coefs_poly_depth[0]*mu_in[inner]+coefs_poly_depth[1])
spear_depth, spear_pval_depth = spearman(mu_in[inner], depth_local[:,0][inner], depth_local[:,1][inner])
spearr_depth, spearr_pval_depth = spearmanr(mu_in[inner], depth_local[:,0][inner])

print('Line-center intensity in function of mu')
print('\n fit values, m = '+str(coefs_poly_depth[0])[:5]+'±'+str(np.sqrt(cov_poly_width[0,0]))[:5]+', b = '+str(coefs_poly_depth[1])[:5]+'±'+str(np.sqrt(cov_poly_width[1,1]))[:5])
print('Χ² = '+str(chi_depth))
print('pearson = '+str(pearson_depth))
print('r² = '+str(r2_depth))
print('spearman = '+str(spearr_depth))
print('p-value = '+str(np.log10(spearr_pval_depth)))
# Out:
# Central RV in function of orbital phases
#
#  fit values, m = 166.71±0.9160, b = -0.028±0.0052
# Χ² = [0.08632471891128349, 18.19057210060134]
# pearson = 0.9998768076497558
# r² = 0.9997333272331969
# spearman = 1.0
# p-value = -inf
#
#
# Line-width measure in function of mu
#
# fit values, m = -0.27±0.095, b = 3.211±0.062
# Χ² = [85.41741419243026, 193.76307890022775]
# pearson = -0.7013530263061573
# r² = 0.4852829549182557
# spearman = -0.6923076923076923
# p-value = -2.2167362797663746
#
#
# Line-center intensity in function of mu
#
#  fit values, m = -14.0±2.062, b = 38.92±1.330
# Χ² = [183.02932103615132, 1220.0469324296841]
# pearson = -0.895994385020751
# r² = 0.7951989269965862
# spearman = -0.9208791208791209
# p-value = -5.525558899332922

# %%
#spearman and p-value distributions
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(27,12))

axes[0,0].hist(np.concatenate((spear_x0[2:], spear_x0[:2]-0.005)), density=True, color='black', bins=10)
axes[0,0].set_title('Central radial velocities')
axes[0,0].set_xlabel('Spearman correlation coefficient')
axes[0,0].set_ylabel('Probability')
axes[0,0].set_xlim((0.95,1))

axes[1,0].hist(np.concatenate((spear_pval_x0[2:], spear_pval_x0[:2]+0.0000001)), density=True, color='black', bins=50)
axes[1,0].set_xlabel('p-value')
axes[1,0].set_ylabel('probability')


axes[0,1].hist(spear_width, density=True, color='black', bins=50)
axes[0,1].set_title('Line-width measure')
axes[0,1].set_xlabel('Spearman correlation coefficient')
axes[0,1].set_ylabel('probability')

axes[1,1].hist(np.log10(spear_pval_width), density=True,color='black',bins=50)
axes[1,1].set_xlabel('log p-value')
axes[1,1].set_ylabel('probability')


axes[0,2].hist(spear_depth,density=True,color='black',bins=30)
axes[0,2].set_title('Line-center intensity')
axes[0,2].set_xlabel('Spearman correlation coefficient')
axes[0,2].set_ylabel('probability')

axes[1,2].hist(np.log10(spear_pval_depth),density=True,color='black',label='day 11 values',bins=30)
axes[1,2].set_xlabel('log p-value')
axes[1,2].set_ylabel('probability')

plt.suptitle('Local white light CCFs')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,8))

axes[0,0].axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange')
axes[0,0].axvspan(tr_ingress_egress/2.-tr_dur/2, tr_dur/2-tr_ingress_egress/2., alpha=0.4, color='orange')
axes[0,0].axhline(y=master_x0, color='red', linestyle='-', lw=3,)
axes[0,0].scatter(in_phases[inner], x0_local[:,0][inner],color='blue',s=50)
axes[0,0].errorbar(x=in_phases[inner], y=x0_local[:,0][inner], yerr=x0_local[:,1][inner], capsize=5, capthick=0.5, color='black', linewidth=0, elinewidth=2)
axes[0,0].plot(in_phases[inner], coefs_poly_rv[0]*in_phases[inner]+coefs_poly_rv[1], color='blue', linestyle='--')
axes[0,0].set_title('Central RVs')
axes[0,0].set_xlabel('Orbital Phase')
axes[0,0].set_ylabel('Radial Velocity [km/s]')
axes[0,0].grid()
axes[0,0].set_axisbelow(True)

axes[1,0].axvspan(0, mu_max, alpha=0.3, color='orange')
axes[1,0].axvspan(mu_min, mu_max, alpha=0.4, color='orange')
axes[1,0].axhline(y=master_x0, color='red', linestyle='-', lw=3)
axes[1,0].scatter(mu_in[inner], x0_local[:,0][inner], color='blue', s=50)
axes[1,0].errorbar(x=mu_in[inner], y=x0_local[:,0][inner], yerr=x0_local[:,1][inner], capsize=5, capthick=0.5, color='black', linewidth=0, elinewidth=2)
axes[1,0].set_xlabel(r'$\mu$')
axes[1,0].set_ylabel('Radial Velocity [km/s]')
axes[1,0].grid()
axes[1,0].set_axisbelow(True)


axes[0,1].axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange')
axes[0,1].axvspan(tr_ingress_egress/2.-tr_dur/2, tr_dur/2-tr_ingress_egress/2., alpha=0.4, color='orange')
axes[0,1].axhline(y=master_width, color='red', linestyle='-', lw=3)
axes[0,1].scatter(in_phases[inner], width_local[:,0][inner],color='blue',s=50)
axes[0,1].errorbar(x=in_phases[inner], y=width_local[:,0][inner], yerr=width_local[:,1][inner],capsize=5,capthick=0.5,color='black',linewidth=0,elinewidth=2)
axes[0,1].set_xlabel('Orbital Phase')
axes[0,1].set_ylabel('Line-width measure [km/s]')
axes[0,1].set_title('Line-width measure')
axes[0,1].grid()
axes[0,1].set_axisbelow(True)

axes[1,1].axvspan(0, mu_max, alpha=0.3, color='orange')
axes[1,1].axvspan(mu_min, mu_max, alpha=0.4, color='orange')
axes[1,1].axhline(y=master_width, color='red', linestyle='-', lw=3)
axes[1,1].scatter(mu_in[inner], width_local[:,0][inner],color='blue',s=50)
axes[1,1].errorbar(x=mu_in[inner], y=width_local[:,0][inner], yerr=width_local[:,1][inner], capsize=5,capthick=0.5,color='black',linewidth=0,elinewidth=2)
axes[1,1].plot(mu_in[inner], coefs_poly_width[0]*mu_in[inner]+coefs_poly_width[1], color='blue', linestyle='--')
axes[1,1].set_xlabel(r'$\mu$')
axes[1,1].set_ylabel('Line-width measure (km/s)')
axes[1,1].grid()
axes[1,1].set_axisbelow(True)


axes[0,2].axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange')
axes[0,2].axvspan(tr_ingress_egress/2.-tr_dur/2, tr_dur/2-tr_ingress_egress/2., alpha=0.4, color='orange')
axes[0,2].axhline(y=master_depth, color='red', linestyle='-', lw=3)
axes[0,2].scatter(in_phases[inner], depth_local[:,0][inner],color='blue',s=50)
axes[0,2].errorbar(x=in_phases[inner], y=depth_local[:,0][inner], yerr=depth_local[:,1][inner],capsize=5,capthick=0.5,color='black',linewidth=0,elinewidth=2)
axes[0,2].set_xlabel('Orbital Phase')
axes[0,2].set_ylabel('Line-center intensity [%]')
axes[0,2].set_title('Line-center intensity')
axes[0,2].grid()
axes[0,2].set_axisbelow(True)

l0=axes[1,2].axvspan(0, mu_max, alpha=0.3, color='orange')
l1=axes[1,2].axvspan(mu_min, mu_max, alpha=0.4, color='orange')
l2=axes[1,2].axhline(y=master_depth, color='red', linestyle='-', lw=3)
axes[1,2].scatter(mu_in[inner], depth_local[:,0][inner], color='blue', s=50)
axes[1,2].errorbar(x=mu_in[inner],y=depth_local[:,0][inner], yerr=depth_local[:,1][inner],capsize=5,capthick=0.5,color='black',linewidth=0,elinewidth=2)
axes[1,2].plot(mu_in[inner], coefs_poly_depth[0]*mu_in[inner]+coefs_poly_depth[1], color='blue', linestyle='--')
axes[1,2].set_xlabel(r'$\mu$')
axes[1,2].set_ylabel('Line-center intensity [%]')
axes[1,2].grid()
axes[1,2].set_axisbelow(True)


plt.suptitle('Local white light CCFs parameters')

labels = ['ingress+egress','middle of transit','master out of transit']
fig.legend([l0,l1,l2], labels=labels, loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.05), fontsize=15)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(ncols=3, figsize=(20,5))

axes[0].axvspan(-tr_dur/2., tr_dur/2., alpha=0.3, color='orange')
axes[0].axvspan(tr_ingress_egress/2.-tr_dur/2, tr_dur/2-tr_ingress_egress/2., alpha=0.4, color='orange')
axes[0].scatter(in_phases[inner], x0_local[:,0][inner]-(coefs_poly_rv[0]*in_phases[inner]+coefs_poly_rv[1]), color='blue', s=50)
axes[0].errorbar(x=in_phases[inner],y=x0_local[:,0][inner]-(coefs_poly_rv[0]*in_phases[inner]+coefs_poly_rv[1]), yerr=x0_local[:,1][inner], capsize=5, capthick=0.5, color='black', linewidth=0, elinewidth=2)
axes[0].set_title('Central RVs')
axes[0].set_xlabel('Orbital Phase')
axes[0].set_ylabel('Radial Velocity [km/s]')
axes[0].grid()
axes[0].set_axisbelow(True)

axes[1].axvspan(0, mu_max, alpha=0.3, color='orange')
axes[1].axvspan(mu_min, mu_max, alpha=0.4, color='orange')
axes[1].scatter(mu_in[inner], width_local[:,0][inner]-(coefs_poly_width[0]*mu_in[inner]+coefs_poly_width[1]), color='blue', s=50)
axes[1].errorbar(x=mu_in[inner], y=width_local[:,0][inner]-(coefs_poly_width[0]*mu_in[inner]+coefs_poly_width[1]), yerr=width_local[:,1][inner], capsize=5, capthick=0.5, color='black', linewidth=0, elinewidth=2)
axes[1].set_title('Line-width measure')
axes[1].set_xlabel(r'$\mu$')
axes[1].set_ylabel('Line-width measure [km/s]')
axes[1].grid()
axes[1].set_axisbelow(True)

l0=axes[2].axvspan(0, mu_max, alpha=0.3, color='orange')
l1=axes[2].axvspan(mu_min, mu_max, alpha=0.4, color='orange')
axes[2].scatter(mu_in[inner], depth_local[:,0][inner]-(coefs_poly_depth[0]*mu_in[inner]+coefs_poly_depth[1]), color='blue', s=50)
axes[2].errorbar(x=mu_in[inner], y=depth_local[:,0][inner]-(coefs_poly_depth[0]*mu_in[inner]+coefs_poly_depth[1]), yerr=depth_local[:,1][inner], capsize=5, capthick=0.5, color='black', linewidth=0, elinewidth=2)
axes[2].set_title('Line-center intensity')
axes[2].set_xlabel(r'$\mu$')
axes[2].set_ylabel('Line-center intensity [%]')
axes[2].grid()
axes[2].set_axisbelow(True)

plt.suptitle('Local white lights CCFs residuals', fontsize=20)

labels = ['ingress+egress','middle of transit']
fig.legend([l0,l1], labels=labels, loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.1))

plt.tight_layout()
plt.show()
